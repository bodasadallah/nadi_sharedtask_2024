# %% [markdown]
# ## Instruction Tuning
#
# Supervised fine tuning (SFT) is fine-tuning all of a model’s parameters on supervised data of inputs and outputs. It teaches the model how to follow user specified instructions. It is typically done after model pre-training. **Source**: http://tinyurl.com/2v884put
#
# ![instruction tuning](assets/instruction-tuning.jpg)
#
# Image Source: https://medium.com/mantisnlp/supervised-fine-tuning-customizing-llms-a2c1edbf22c3
#
# Requirement.
# 1. Pre-trained model & tokenizer -> We will get it from huggingface.
# 2. Instruction-Response pair data -> eg: Alpaca, Dolly, Oasst1, LIMA, etc. We will get the dataset from huggingface.
#
# Steps.
# 1. Load pre-trained model and tokenizer.
# 2. Format the instructions response pair.
# 3. Preprocess the dataset.
# 4. Train the pre-trained model in supervised setting with response as labels and instruction as input.
# 5. Evaluation:
#    i. Automatic Evaluation: Eg: MMLU, BBH, AGIEval, domain-specific evaluation such as maths, reasoning, code.
#    ii. Human Evaluation: Give model prompts to generate a response and ask humans.
#    iii. LLM as Evaluator: Ask powerful models such as GPT4 to rate the response generated by the your finetuned model.
#
#
#
# **Note**: Most of the code were borrowed from original alpaca code here: https://github.com/tatsu-lab/stanford_alpaca/tree/main

# %% [markdown]
# #### Dependencies

# %%
# !pip uninstall transformers
# !pip install git+https://github.com/huggingface/transformers
# !pip install --quiet datasets accelerate -U

# %%
# import dependencies
import os
import copy
import logging
from dataclasses import dataclass, field
from typing import Optional, Dict, Sequence
from tqdm import tqdm
import torch
import datasets
import transformers
from torch.utils.data import Dataset
from transformers import Trainer
from datasets import load_dataset
from transformers.trainer_utils import get_last_checkpoint, is_main_process

# %%
import pandas as pd

# %% [markdown]
# ##### 1. Configs

# %%
model_name_or_path = "UBC-NLP/Jasmine-350M" #"microsoft/phi-1_5" -> use "gpt2" if you have less powerful GPU # huggingface model name
dataset_name_or_path = "macabdul9/NADI-Sample" # LIMA Data in Vicuna Format. https://arxiv.org/abs/2305.11206
cache_dir="cache_dir"
split_name="train"
inst_col_name="instruction"
input_col_name="source_dialect"
output_col_name="target_msa"
model_max_length=512 # how long sequence model can process
IGNORE_INDEX = -100
DEFAULT_PAD_TOKEN = "[PAD]"
DEFAULT_EOS_TOKEN = "</s>"
DEFAULT_BOS_TOKEN = "<s>"
DEFAULT_UNK_TOKEN = "<unk>"

# %% [markdown]
# ##### 2. Dataset Preparation

# %%
# # dataset = load_dataset(dataset_name_or_path)
# # Download the NADI dataset
# #Donwload FT code and sample for subtask1
# !wget https://raw.githubusercontent.com/UBC-NLP/nadi/main/run_NADI2023_country_level.py /content/run_NADI2023_country_level.py
# !wget https://raw.githubusercontent.com/UBC-NLP/nadi/main/NADI2023_subtast1_sample.tsv NADI2023_subtast1_sample.tsv
# #FT code and sample for subtask2 and subtask3
# !wget https://raw.githubusercontent.com/UBC-NLP/nadi/main/run_NADI2023_MT.py /content/run_NADI2023_MT.py
# !wget https://raw.githubusercontent.com/UBC-NLP/nadi/main/NADI2023_MT_examples.tsv /content/NADI2023_MT_examples.tsv

# %%
import pandas as pd
import datasets

# %%
# df = pd.read_csv("NADI2023_MT_examples.tsv", sep="\t")

# %%
# dataset = datasets.Dataset.from_pandas(df)

# %%
# dataset.push_to_hub("NADI-Sample", max_shard_size="500MB", token="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")

# %%
# dataset = datasets.load_dataset("macabdul9/NADI-Sample")

# %%
# dataset

# %% [markdown]
# - This is two prompt template / or wrapper we are going to use.
# - Some instruction contains

# %%
PROMPT_DICT = {
    "prompt_input": (
        "Below is an instruction that describes a task, paired with an input that provides further context. "
        "Write a response that appropriately completes the request.\n\n"
        "### Instruction:\n{instruction}\n\n### Input:\n{input}\n\n### Response:"
    ),
    "prompt_no_input":(
        "Below is an instruction that describes a task. "
        "Write a response that appropriately completes the request.\n\n"
        "### Instruction:\n{instruction}\n\n### Response:"
    ),
    # "translation":(
    #     "Input:{source_dialect}\nOutput:{target_msa}"
    # )
    # "translation":(
    #     "Below is an instruction that describes a task, paired with an input that provides further context. "
    #     "Write a response that appropriately completes the request.\n\n"
    #     "### Instruction:\nTranslate this sentence from dialect arabic to Modern standard Arabic\n\n### Input:\n{source_dialect}\n\n### Response:"
    # ),
    "translation":(
        "ترجم الجملة من العامية الى العربية الفصحي الجملة هي:\n{source_dialect}\n\n### وهذة هى ترجمة الجملة:"
    ),
}

# %% [markdown]
# If we are adding any new tokens to then we need to extend the embedding.

# %%
def smart_tokenizer_and_embedding_resize(
    special_tokens_dict: Dict,
    tokenizer: transformers.PreTrainedTokenizer,
    model: transformers.PreTrainedModel,
):
    """Resize tokenizer and embedding.

    Note: This is the unoptimized version that may make your embedding size not be divisible by 64.
    """
    num_new_tokens = tokenizer.add_special_tokens(special_tokens_dict)
    model.resize_token_embeddings(len(tokenizer))

    if num_new_tokens > 0:
        input_embeddings = model.get_input_embeddings().weight.data
        output_embeddings = model.get_output_embeddings().weight.data

        input_embeddings_avg = input_embeddings[:-num_new_tokens].mean(dim=0, keepdim=True)
        output_embeddings_avg = output_embeddings[:-num_new_tokens].mean(dim=0, keepdim=True)

        input_embeddings[-num_new_tokens:] = input_embeddings_avg
        output_embeddings[-num_new_tokens:] = output_embeddings_avg

# %% [markdown]
# ### Tokenize the data.

# %%
def _tokenize_fn(strings: Sequence[str], tokenizer: transformers.PreTrainedTokenizer) -> Dict:
    """Tokenize a list of strings."""
    tokenized_list = [
        tokenizer(
            text,
            return_tensors="pt",
            padding="longest",
            max_length=tokenizer.model_max_length,
            truncation=True,
        )
        for text in strings
    ]
    input_ids = labels = [tokenized.input_ids[0] for tokenized in tokenized_list]
    input_ids_lens = labels_lens = [
        tokenized.input_ids.ne(tokenizer.pad_token_id).sum().item() for tokenized in tokenized_list
    ]
    return dict(
        input_ids=input_ids,
        labels=labels,
        input_ids_lens=input_ids_lens,
        labels_lens=labels_lens,
    )

# %%
def preprocess(
    sources: Sequence[str],
    targets: Sequence[str],
    tokenizer: transformers.PreTrainedTokenizer,
) -> Dict:
    """Preprocess the data by tokenizing."""
    examples = [s + t for s, t in zip(sources, targets)]
    examples_tokenized, sources_tokenized = [_tokenize_fn(strings, tokenizer) for strings in (examples, sources)]
    input_ids = examples_tokenized["input_ids"]
    labels = copy.deepcopy(input_ids)
    for label, source_len in zip(labels, sources_tokenized["input_ids_lens"]):
        label[:source_len] = IGNORE_INDEX
    return dict(input_ids=input_ids, labels=labels)

# %%
# dataset = load_dataset('csv', data_files='/home/mostafa.awad/nlp702-assignment-3/dataset/train/madar/train_standard_madar#ar.tsv',
#  delimiter='\t',
#  column_names=['source_dialect', 'target_msa'])

# %%
# dataset = load_dataset('csv', data_files=train_data_path,
#                         delimiter='\t',
#                         column_names=['source_dialect', 'target_msa'])

# logging.warning("Formatting inputs...")
# # if there is no input for prompt the use prompt_no_input template else use prompt_input template
# prompt_input, prompt_no_input, prompt_translation = PROMPT_DICT["prompt_input"], PROMPT_DICT["prompt_no_input"], PROMPT_DICT["translation"]
# # sources = [
# #     prompt_input.format_map(example) if example.get(input_col_name, "") != "" else prompt_no_input.format_map(example)
# #     for example in tqdm(dataset)
# # ]
# sources = [prompt_translation.format_map(example) for example in dataset['train']]

# targets = [f"{example[output_col_name]}{tokenizer.eos_token}" for example in dataset['train']]

# %%
class SupervisedDataset(Dataset):
    """Dataset for supervised fine-tuning."""

    def __init__(self, dataset_name_or_path: str, tokenizer: transformers.PreTrainedTokenizer):
        super(SupervisedDataset, self).__init__()

        # Load the dataset
        logging.warning("Loading data...")
        # 1. Load tsv file 2. Convert them into hf dataset
        # df = pd.read_csv(dataset_name_or_path
        # dataset = datasets.load_dataset(dataset_name_or_path, split=split_name)
        dataset = load_dataset('csv', data_files=dataset_name_or_path,
                                delimiter='\t',
                                column_names=['source_dialect', 'target_msa'])

        logging.warning("Formatting inputs...")
        # if there is no input for prompt the use prompt_no_input template else use prompt_input template
        prompt_input, prompt_no_input, prompt_translation = PROMPT_DICT["prompt_input"], PROMPT_DICT["prompt_no_input"], PROMPT_DICT["translation"]
        # sources = [
        #     prompt_input.format_map(example) if example.get(input_col_name, "") != "" else prompt_no_input.format_map(example)
        #     for example in tqdm(dataset)
        # ]
        sources = [prompt_translation.format_map(example) for example in dataset['train']]
        
        targets = [f"{example[output_col_name]}{tokenizer.eos_token}" for example in dataset['train']]

        logging.warning("Tokenizing inputs... This may take some time...")
        data_dict = preprocess(sources, targets, tokenizer)

        self.input_ids = data_dict["input_ids"]
        self.labels = data_dict["labels"]

    def __len__(self):
        return len(self.input_ids)

    def __getitem__(self, i) -> Dict[str, torch.Tensor]:
        return dict(input_ids=self.input_ids[i], labels=self.labels[i])

# %%
# for example in dataset['train']:
#     print(example.get(input_col_name, "input"))
#     break

# %%
# dataset = SupervisedDataset(dataset_name_or_path=dataset_name_or_path, tokenizer=tokenizer)

# %%
# prompt_input, prompt_no_input, prompt_translation = PROMPT_DICT["prompt_input"], PROMPT_DICT["prompt_no_input"], PROMPT_DICT["translation"]

# %%
# sources = [prompt_translation.format_map(example) for example in dataset['train']]

# %%
# sources

# %%
@dataclass
class DataCollatorForSupervisedDataset(object):
    """Collate examples for supervised fine-tuning."""

    tokenizer: transformers.PreTrainedTokenizer

    def __call__(self, instances: Sequence[Dict]) -> Dict[str, torch.Tensor]:
        input_ids, labels = tuple([instance[key] for instance in instances] for key in ("input_ids", "labels"))
        input_ids = torch.nn.utils.rnn.pad_sequence(
            input_ids, batch_first=True, padding_value=self.tokenizer.pad_token_id
        )
        labels = torch.nn.utils.rnn.pad_sequence(labels, batch_first=True, padding_value=IGNORE_INDEX)
        return dict(
            input_ids=input_ids,
            labels=labels,
            attention_mask=input_ids.ne(self.tokenizer.pad_token_id),
        )

# %%
train_data_path = '/home/mostafa.awad/nlp702-assignment-3/dataset/train/madar/train_standard_madar#ar.tsv'
val_data_path = '/home/mostafa.awad/nlp702-assignment-3/dataset/train/madar/val_standard_madar#ar.tsv'
def make_supervised_data_module(tokenizer: transformers.PreTrainedTokenizer) -> Dict:
    """Make dataset and collator for supervised fine-tuning."""
    train_dataset = SupervisedDataset(tokenizer=tokenizer, dataset_name_or_path=train_data_path)
    val_dataset = SupervisedDataset(tokenizer=tokenizer, dataset_name_or_path=val_data_path)
    data_collator = DataCollatorForSupervisedDataset(tokenizer=tokenizer)
    return dict(train_dataset=train_dataset, eval_dataset=val_dataset, data_collator=data_collator)

# %%
def safe_save_model_for_hf_trainer(trainer: transformers.Trainer, output_dir: str):
    """Collects the state dict and dump to disk."""
    state_dict = trainer.model.state_dict()
    if trainer.args.should_save:
        cpu_state_dict = {key: value.cpu() for key, value in state_dict.items()}
        del state_dict
        trainer._save(output_dir, state_dict=cpu_state_dict)  # noqa

# %%
def train(training_args):

    model = transformers.AutoModelForCausalLM.from_pretrained(
        model_name_or_path,
        cache_dir=cache_dir,
        device_map="auto"
    ).to("cuda")
    model.config.use_cache=False

    tokenizer = transformers.AutoTokenizer.from_pretrained(
        model_name_or_path,
        cache_dir=cache_dir,
        model_max_length=model_max_length,
        padding_side="right",
        use_fast=False,
    )
    
    if tokenizer.pad_token is None:
        smart_tokenizer_and_embedding_resize(
            special_tokens_dict=dict(pad_token=DEFAULT_PAD_TOKEN),
            tokenizer=tokenizer,
            model=model,
        )
    if "llama" in model_name_or_path:
        tokenizer.add_special_tokens(
            {
                "eos_token": DEFAULT_EOS_TOKEN,
                "bos_token": DEFAULT_BOS_TOKEN,
                "unk_token": DEFAULT_UNK_TOKEN,
            }
        )

    data_module = make_supervised_data_module(tokenizer=tokenizer)

    # update training args to make output dir
    output_dir = os.path.join(training_args.output_dir, model_name_or_path.split("/")[-1])
    os.makedirs(output_dir, exist_ok=True)

    training_args.output_dir = output_dir

    trainer = Trainer(model=model, tokenizer=tokenizer, args=training_args, **data_module)

    # resume from last checkpoint if it exists
    checkpoint = get_last_checkpoint(training_args.output_dir)

    if checkpoint:
        print(f"Checkpoint found! Training from {checkpoint} checkpoint!")
        trainer.train(resume_from_checkpoint=checkpoint)
    else:
        print(f"No checkpoint found! Training from scratch!")
        trainer.train()

    # trainer.train()
    # save states
    trainer.save_state()
    safe_save_model_for_hf_trainer(trainer=trainer, output_dir=training_args.output_dir)
    print(f"Training finished! Saved model to {training_args.output_dir}.")

# %% [markdown]
# ### Train

# %%
output_dir = "output_new_prompt_short_ar"

# %%
training_args = transformers.TrainingArguments(
    output_dir=output_dir,
    evaluation_strategy = "epoch",  # Evaluate every 'eval_steps' steps
    overwrite_output_dir=True,
    per_device_train_batch_size=16,
    gradient_accumulation_steps=8,
    num_train_epochs=10,
    logging_strategy="epoch",  # Log training loss every epoch
    save_strategy="epoch",  # Save checkpoints every epoch

)

# %%
# training_args = TrainingArguments(
#     "output_dir",
#     evaluation_strategy = "epoch",
#     save_strategy = "epoch",
#     logging_strategy = "epoch",
#     per_device_train_batch_size = 8,
#     per_device_eval_batch_size = 8,
#     num_train_epochs = 3,
#     logging_dir = "logs",
# )

# %%
# transformers.TrainingArguments?

# %%
# training
train(training_args=training_args)
# Out:
# WARNING:root:Loading data...
# WARNING:root:Formatting inputs...
# WARNING:root:Tokenizing inputs... This may take some time...
# WARNING:root:Loading data...
# WARNING:root:Formatting inputs...
# WARNING:root:Tokenizing inputs... This may take some time...
# /home/mostafa.awad/.conda/envs/nlp_assignment2/lib/python3.9/site-packages/accelerate/accelerator.py:432: FutureWarning: Passing the following arguments to `Accelerator` is deprecated and will be removed in version 1.0 of Accelerate: dict_keys(['dispatch_batches', 'split_batches', 'even_batches', 'use_seedable_sampler']). Please pass an `accelerate.DataLoaderConfiguration` instead:
# dataloader_config = DataLoaderConfiguration(dispatch_batches=None, split_batches=False, even_batches=True, use_seedable_sampler=True)
#   warnings.warn(
# No checkpoint found! Training from scratch!
# ERROR:wandb.jupyter:Failed to detect the name of this notebook, you can set it manually with the WANDB_NOTEBOOK_NAME environment variable to enable code saving.
# wandb: Currently logged in as: mostafa-3zazi (mostafa-azazi). Use `wandb login --relogin` to force relogin
# wandb version 0.16.6 is available!  To upgrade, please run:
#  $ pip install wandb --upgrade
# Tracking run with wandb version 0.16.4
# Run data is saved locally in <code>/home/mostafa.awad/nlp702-assignment-3/wandb/run-20240503_201325-x87qjzv6</code>
# Syncing run <strong><a href='https://wandb.ai/mostafa-azazi/huggingface/runs/x87qjzv6' target="_blank">output_new_prompt_short_ar</a></strong> to <a href='https://wandb.ai/mostafa-azazi/huggingface' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>
#  View project at <a href='https://wandb.ai/mostafa-azazi/huggingface' target="_blank">https://wandb.ai/mostafa-azazi/huggingface</a>
#  View run at <a href='https://wandb.ai/mostafa-azazi/huggingface/runs/x87qjzv6' target="_blank">https://wandb.ai/mostafa-azazi/huggingface/runs/x87qjzv6</a>
#     <div>
#
#       <progress value='2280' max='2280' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [2280/2280 15:26, Epoch 9/10]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>2.699800</td>
#       <td>2.508303</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>1.955300</td>
#       <td>2.504355</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>1.578200</td>
#       <td>2.752396</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>1.268500</td>
#       <td>2.997625</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>1.056400</td>
#       <td>3.375811</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.905100</td>
#       <td>3.583266</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>0.791900</td>
#       <td>3.917618</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>0.636900</td>
#       <td>4.449270</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>0.593000</td>
#       <td>4.616311</td>
#     </tr>
#   </tbody>
# </table><p>
# Training finished! Saved model to output_new_prompt_short_ar/Jasmine-350M.

# %%
/home/mostafa.awad/nlp702-assignment-3/output_new/Jasmine-350M/checkpoint-1368

# %% [markdown]
# # inference

# %%
model_name_or_path = "/home/mostafa.awad/nlp702-assignment-3/output_new_prompt_short/Jasmine-350M/checkpoint-456"
# model_name_or_path = "UBC-NLP/Jasmine-350M"

# %%
model = transformers.AutoModelForCausalLM.from_pretrained(
    model_name_or_path,
    cache_dir=cache_dir,
    device_map="auto"
).to("cuda")
model.config.use_cache=False

tokenizer = transformers.AutoTokenizer.from_pretrained(
    model_name_or_path,
    cache_dir=cache_dir,
    model_max_length=model_max_length,
    padding_side="right",
    use_fast=False,
)

if tokenizer.pad_token is None:
    smart_tokenizer_and_embedding_resize(
        special_tokens_dict=dict(pad_token=DEFAULT_PAD_TOKEN),
        tokenizer=tokenizer,
        model=model,
    )
if "llama" in model_name_or_path:
    tokenizer.add_special_tokens(
        {
            "eos_token": DEFAULT_EOS_TOKEN,
            "bos_token": DEFAULT_BOS_TOKEN,
            "unk_token": DEFAULT_UNK_TOKEN,
        }
    )

# %%
model.eval()
# Out:
# GPTNeoForCausalLM(
#   (transformer): GPTNeoModel(
#     (wte): Embedding(64001, 768)
#     (wpe): Embedding(2048, 768)
#     (drop): Dropout(p=0.0, inplace=False)
#     (h): ModuleList(
#       (0-11): 12 x GPTNeoBlock(
#         (ln_1): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#         (attn): GPTNeoAttention(
#           (attention): GPTNeoSelfAttention(
#             (attn_dropout): Dropout(p=0.0, inplace=False)
#             (resid_dropout): Dropout(p=0.0, inplace=False)
#             (k_proj): Linear(in_features=768, out_features=768, bias=False)
#             (v_proj): Linear(in_features=768, out_features=768, bias=False)
#             (q_proj): Linear(in_features=768, out_features=768, bias=False)
#             (out_proj): Linear(in_features=768, out_features=768, bias=True)
#           )
#         )
#         (ln_2): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#         (mlp): GPTNeoMLP(
#           (c_fc): Linear(in_features=768, out_features=3072, bias=True)
#           (c_proj): Linear(in_features=3072, out_features=768, bias=True)
#           (act): NewGELUActivation()
#           (dropout): Dropout(p=0.0, inplace=False)
#         )
#       )
#     )
#     (ln_f): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#   )
#   (lm_head): Linear(in_features=768, out_features=64001, bias=False)
# )

# %%
evaluation_file_path = "/home/mostafa.awad/nlp702-assignment-3/dataset/NADI2024_subtask3_dev.tsv"

# %%
dataset = load_dataset('csv', data_files=evaluation_file_path,
                                delimiter='\t',
                                column_names=['source_dialect', 'target_msa'])
# Out:
# Generating train split: 0 examples [00:00, ? examples/s]

# %%
prompt_eval = PROMPT_DICT['translation']

# %%
# prompt_input, prompt_no_input, prompt_translation = PROMPT_DICT["prompt_input"], PROMPT_DICT["prompt_no_input"], PROMPT_DICT["translation"]

# sources = [prompt_translation.format_map(example) for example in dataset['train']]
# targets = [f"{example[output_col_name]}{tokenizer.eos_token}" for example in dataset['train']]
eval = [prompt_eval.format_map(example) for example in dataset['train']]

# %%
eval[1]
# Out:
# 'Input:\nطّلع الرجالة اللي انت عايزهم من الجراج و قطاع النقل يمشّطوا المناطق دي لحد ما يلاقوهم.\n\n### Response:'

# %%
len(eval[1:])
# Out:
# 400

# %%
generate = transformers.pipeline(
    "text-generation",
    model=model,
    tokenizer=tokenizer,
    )

generated_text = generate(
eval,
do_sample=True,
num_return_sequences=1,
eos_token_id=tokenizer.eos_token_id,
return_full_text=False,
max_new_tokens=64,
temperature=0.9,
top_p=0.99,
top_k=40,
repetition_penalty=1.1
)

# if interface_args.output_file_path:
#     save_result(generated_text,interface_args)
# else:
#     for text in generated_text:
#         print(text[0])
# Out:
# /home/mostafa.awad/.conda/envs/nlp_assignment2/lib/python3.9/site-packages/transformers/generation/configuration_utils.py:415: UserWarning: `do_sample` is set to `False`. However, `top_p` is set to `0.95` -- this flag is only used in sample-based generation modes. You should set `do_sample=True` or unset `top_p`.
#   warnings.warn(

# %%
l = []
for text in generated_text:
    l.append(text[0]['generated_text'])

# %%
# File path to save the list
file_path = "jasmine_out.txt"

# Open the file in write mode
with open(file_path, 'w') as file:
    # Write each element of the list to the file
    for item in l:
        file.write(f"{item}\n")

# %%
len(l)
# Out:
# 400

# %%
generated_text
# Out:
# [[{'generated_text': 'Input:\nsource_da\n\n### Response:هل من الممكن أن تخبرني عن كيفية الوصول إلى هناك من فضلك ؟'}],
#  [{'generated_text': 'Input:\nطّلع الرجالة اللي انت عايزهم من الجراج و قطاع النقل يمشّطوا المناطق دي لحد ما يلاقوهم.\n\n### Response:أخرج الرجّال من جراج و اتجه إلى منطقة التسوق هذه حتى يتم العثور عليهم.'}],
#  [{'generated_text': 'Input:\nخمسة و ستين قلم ده لازم يبقي معاه كلكوليتر ساعتها و لا ايه؟ \n\n### Response:خمسة وسبعون قلم رصاص هذا يجب أن يكون مع كل قلم رصاص ساعتها أيضاً.'}],
#  [{'generated_text': 'Input:\nأنا بس عايزك ترتبي نفسك من دلوقتي إنك تبقي زي ستات عيلة الدالي.\n\n### Response:أريد أن أرتب نفسي من الآن.'}],
#  [{'generated_text': 'Input:\nبصوا بقى أنا اللي استنيت و أنا اللي كسبت و أنا اللي حلمت يعني كل ده من حقي أنا أنا عارف طبعاً ان كل واحد فيكوا كان بيساعدنا، أبو النجا كان بيساعد من مرتبه يشكر، جعيدي كان بيأكلنا من الزرع اللي بيعمله فوق السطوح و يشكر، بيبيتو كان بيسرح علينا بالجيتار و يشحت يشكر، أنا برضو مش ناسي كل ده و ان شاء الله هيكون يعني عندي. \n\n### Response:حسناً ، لقد اشتريت هذا من فضلك ، شكراً جزيلاً لك.'}],
#  [{'generated_text': 'Input:\nيعني بتاع الرياسة اللي كلمك مقالكش هما عايزينك في ايه؟\n\n### Response:هل يمكنك أن تخبرني كيف يمكنني أن أقابلك في هذا الموقف ؟'}],
#  [{'generated_text': 'Input:\nانت جاي لحد هنا عشان تتهمني بالزور بتهمه أنا مليش علاقة بيها؟\n\n### Response:هل يمكنك أن تخبرني كيف أتحكم في مشاعري ؟'}],
#  [{'generated_text': 'Input:\nالمدام جايه معانا عشان زي ما تقولي حضرتك انها يعني معادها قرّب فبتلف معانا عشان يعني لو ربنا كرم و حصل تبقى قدامنا و نلحقها عقبال عندك يا حبيبتي عقبال عندك. \n\n### Response:أنا قادم من اليابان في حوالي الساعة السابعة صباحاً.'}],
#  [{'generated_text': 'Input:\nمعلش يا سعد حقك عليا بس كنت حتجنن لما شوفت دراع البت.\n\n### Response:شكراً لك يا سيدي على دعوتك لي.'}],
#  [{'generated_text': 'Input:\nبس في الحقيقة أنا مستغرب من اهتمامك المفاجئ بالواد الصحفي ده. \n\n### Response:أنا مسرور حقاً لوجودك هنا.'}],
#  [{'generated_text': 'Input:\nخمسين الف متر دول في طريق السويس، الاتنين و سبعين الف متر دول في زمام القطامية، المنطقة بقى من عند الكيلو تلاتة للكيلو تلاتة و عشرين طريق مصر اسكندرية الصحرواي فيها سبع حتت يعملوا يعملوا حوالي عشر الاف فدان. \n\n### Response:مائتي ألف دولاراً في طريق رقم واحد في منطقة القطامية ، المنطقة بقي فيها حوالي سبعة عشر ألف فدان. '}],
#  [{'generated_text': 'Input:\nأنا متطلبتش من حد انه يعور الراجل اللي كان عند مدام الفت. \n\n### Response:لقد طلبت من شخص ما أن يعيرني شيئاً من فضلك.'}],
#  [{'generated_text': 'Input:\nطب بص يا استاذ ايه رأيك حضرتك لو نبني ديكور؟\n\n### Response:أهلا ، شكراً جزيلاً.'}],
#  [{'generated_text': 'Input:\nمش عارف حكاية اللي اسمه سعد الدالي ده ايه! كل يوم و التاني له حكاية، مره ابنه و مره مراته. حقه اللي اسمها ايه دي اسمها ايه دي؟\n\n### Response:لا أعرف شيئاً عن هذا الاسم.'}],
#  [{'generated_text': 'Input:\nطب ايه بقى اللي انت قولته و خليت الريس يقلب عليك بالشكل ده؟ \n\n### Response:ماذا قلت للسيد الرئيس ؟'}],
#  [{'generated_text': 'Input:\nبحترم رغبة سعد في انها تفضل موجودة في السوق و بقوة من غير خلافات و لا هزات سعد لو عرف اللي عمله خالد الدالي مش هيرحمه. \n\n### Response:أشكرك شكرا جزيلاً على مشاعرك الطيبة.'}],
#  [{'generated_text': 'Input:\nهو ايه العبارة يا خونا ايه يا استاذ مش الاستاذ بيبتو ولامؤاخزة هو اللي كان مشلول\n\n### Response:ما هي العبارة يا سيدي ؟'}],
#  [{'generated_text': 'Input:\nكبرت و هولعلكوا في كل حاجتكوا و هحرق قلبكوا زي ما حرقتوا قلبي.\n\n### Response:لقد كبر حجمي و هولع في كل شيء. سأحرق كل مشاعرك وأحاسيسك.'}],
#  [{'generated_text': 'Input:\nاسمحلي يا سعد أنا مش موافق علي الخطوة دي مش موافق خالص ده انتحار رسمي مش نصر اقتصادي. \n\n### Response:أرجو المعذرة يا سيدي. أنا لا أستطيع الموافقة على هذه الأمر. إنه انتحار رسمي لا مفر منه.'}],
#  [{'generated_text': 'Input:\nمين يالا اللي علمك الحركة اللذيذة دي؟ علمهاني علمهاني بتتكلم و انت بؤك مقفول؟\n\n### Response:من فضلك أخبرني عن كيفية تعليمك هذه الحركة الجميلة. هل يمكنك أن تخبرني عن كيفية نطق هذه الكلمات من فضلك ؟'}],
#  [{'generated_text': 'Input:\nعشان أعرف مين اللي ورا الحادثة بتاعتي أنا و حسام؟\n\n### Response:هل من الممكن أن تخبرني من هو الشخص الذي يقف خلف الحادثة ؟'}],
#  [{'generated_text': 'Input:\n بقى يا ربي حتى ماما مش عارف الاقيلها مدخل و بعدين جوازة ايه المفاجئة اللي بابا محضرهالي دي هو أنا ايه مليش رأي في البيت ده ؟\n\n### Response:حسناً.'}],
#  [{'generated_text': 'Input:\nبلا مسقعة بلا رز بلبن اقعد ساكت بلاش كلام فارغ.\n\n### Response:لا مسخن بلا أرز, من فضلك.'}],
#  [{'generated_text': 'Input:\nو ايه الاحتمال بقى اللي جه بال العبقري ده و مجاش على بالنا احنا؟\n\n### Response:ماذا عن هذا العبقري الذي لم يره أحد من قبل ؟'}],
#  [{'generated_text': 'Input:\nاندهش من اجابتي ليه، قولتله يا فندم يشرفني اني يتقال عليا معلم حتى لو معايا دكتوراه في الهندسة\n\n### Response:هل يمكنك أن تخبرني كيف يمكنني أن أتعرف على شخصية هذا الشخص ، من فضلك ؟'}],
#  [{'generated_text': 'Input:\nو انتي يا بابا انتي رقبتك برقبة الواد كريم التخين الوحش. \n\n### Response:يا سيدي أنت يا بابا أنت رقبتك على رقبتك. من فضلك احتفظ بالباقي لك.'}],
#  [{'generated_text': 'Input:\nأنا معجبه بصراحة ربنا بأفكاري لان لولا أفكاري اللي أنا فكرتها الفوكيره دي البت دي مكانتش قلبها حيرق و تشغلنا. \n\n### Response:أنا معجّب جداً بإقتراحاتي لأن أفكاري هي التي تقودني إليها تفكيري.'}],
#  [{'generated_text': 'Input:\nده ظلم ظلم و الله العظيم أنا لا يمكن أعمل أي حاجة ضد سعد بيه الدالي كل اللي حصل اني كنت رايحة عشان اطمن عليه. \n\n### Response:هذا ظلم كبير. إنه لا يمكن أن أعمل أي شيء ضد هذا الرجل.'}],
#  [{'generated_text': 'Input:\nيا تنزلي مع ماما ألفت تشتغلي معاها في الى قالتلك عليه،\n\n### Response:هل من الممكن أن تخبرني عن اسمك وعنوانك البريدي وعنوان البريد الإلكتروني الخاص بك ، من فضلك ؟'}],
#  [{'generated_text': 'Input:\nو هما أربع سنين دول قليلين أنا أول شركة كبيرة عملتها في أربع سنين، الأربع سنين اللي بعدهم عملت أول مليون جنيه. \n\n### Response:أربع سنوات قليلة جداً. إنها أقل من أربعة سنوات بقليل. منذ أن بدأت العمل بها في أربع سنوات ؟'}],
#  [{'generated_text': 'Input:\nلا ازاي بقى؟ انت نسيت يومين مهمين جدا معقولة! العيد الصغير والعيد الكبير\n\n### Response:كيف حالك ؟ لقد نسيت يوماً هاماً جداً حقاً ، أليس كذلك ؟ هل يمكنك أن تخبرني كيف قضيت هذا اليوم الهام ؟'}],
#  [{'generated_text': 'Input:\nيعني محدش قال مرشي يا رودي، تسلم ايدك يا رورو، أي حاجة من الحاجات دي!\n\n### Response:هل من الممكن أن تخبرني عن مرشدي ، يا رودي ؟ شكراً جزيلاً.'}],
#  [{'generated_text': 'Input:\nمحدش عارف الملعب حيفضل فاضي قد ايه قبل ما يرجع فيه سعد الدالي تاني؟ \n\n### Response:لا أحد يعرف المكان الذي ستقام فيه مباراة كرة قدم اليوم.'}],
#  [{'generated_text': 'Input:\nعدم المؤاخزة، الفت هانم أمرت بدخول عم عطيه حالاَ، اتفضل يا عم عطيه، اتفضل.\n\n### Response:هل من الممكن أن تخبرني كيف أصل إلى هناك من فضلك ؟'}],
#  [{'generated_text': 'Input:\nو اخترعتي أحداث و مشاكل و لا أفلام زمان طب و بعدين؟ \n\n### Response:من فضلك اختر شيئاً جيداً ، من فضلك.'}],
#  [{'generated_text': 'Input:\nلكن تأكد لو كان عفان الويشي اللي كان ورا محاولة اغتيالي. \n\n### Response:فقط تأكد من أن كل شيء على ما يرام.'}],
#  [{'generated_text': 'Input:\n توكلت على الله ووضعت يدي في يد مجموعة من الاخوان و قولنا بس ان شاء الله على بركة الله يعني تكون البداية من هنا. \n\n### Response:لقد وضعت يدي في يدي مجموعة من أخواتنا وأخشى أن لا نكون على مقربة من بعضنا البعض.'}],
#  [{'generated_text': 'Input:\nوكريم ينهي دراسته بكلية التجارة ويبحث عن الجائزة  الكبري في اعلانات الشاي او اللبان\n\n### Response:من فضلك سجل اسمك وعنوانك ورقم تليفونك وعنوان البريد الإلكتروني الخاص بك.'}],
#  [{'generated_text': 'Input:\nمعلش يا سعد بيه لولا اننا عارف ان الموضوع يهمك جداَ و يعتبر تطور بالنسبة لنا في قضيتك ماكنتش طلبت من حضرتك تيجي هنا تاني و بالسرعه دي.\n\n### Response:حسناً.'}],
#  [{'generated_text': 'Input:\nيا بني يا حبيبي يا بني يا حبيبي افهمني أنا عايز شقة حقيرة عايز حيطان مكسرة تواليتات طافحة عايز شبابيك بايظة انت مبتفهمش.\n\n### Response:أرجو المعذرة يا سيدي.'}],
#  [{'generated_text': 'Input:\nبلاش خلافات و تعطّلوا المجموعة الأحسن نحط ايدينا في ايدين بعض عشان نفضل راكبين السوق.\n\n### Response:لا بد أن تكون حذراً ، من فضلك.'}],
#  [{'generated_text': 'Input:\nيا سعد السوق كله بيحسدوا على علاقكتوا ببعض و انت عارف ده كويس. \n\n### Response:يا سيدى السوق كله يحسدكم على علاقتكم ببعض و أنت تعرف ذلك جيداً.'}],
#  [{'generated_text': 'Input:\nسيادتك اطّلع علي الأوراق دي بنفسك عشان تعرف الموضوع رسي على مين و تعرف سعادتك حجم الكارثة اللي عملها ناصف مدكور قصدي ناصف بيه مدكور. \n\n### Response:سيادة رئيس تحرير هذه الصحيفة ، أود أن أطلعك على هذه الأوراق من أجل أن تعرف ما هي الكارثة التي حدثت للسيد ناصف. أطلعت السيد ناصف على حقيقة ما حدث للسيد مدكور. '}],
#  [{'generated_text': 'Input:\nمدحت قولي يا مدحت قولي مين أبويا مش عارف أطلع بطاقة لحد دلوقتي يا مدحت قولي مين أمي أرجوك؟\n\n### Response:من فضلك أخبرني من فضلك ما هو اسم والدك.'}],
#  [{'generated_text': 'Input:\nده من سبع سنين و بعد كده اتعودت مع مجلس إدارة الثورة بشكل طبيعي لحد ما قدمت استقالتي و بقيت أشتغل بره مصر و جوه مصر و بعدين في النهاية أنا من أشد المؤمنين بمبادئ الثورة و أفكارها.\n\n### Response:هذا من سبع سنوات و بعد ذلك نشأت مع المجلس الثوري بشكل طبيعي جداً إلى أن قدمت استقالي و أصبحت موظفاً في مصر و في الخارج.'}],
#  [{'generated_text': 'Input:\nوعد الحر ديناً عليه روح قول لصحابك ان بسبوسة اتنازلت عن القضية. \n\n### Response:هل لك أن تحضر لي بعض القهوة من فضلك ؟'}],
#  [{'generated_text': 'Input:\nجعجع مين دول يا خويا اللي عاوزين ياخدوا زمارة رقبتك؟ \n\n### Response:هل من الممكن أن أحصل على بعض الماء من فضلك ؟'}],
#  [{'generated_text': 'Input:\nبسبوسة عندها حق و بعدين أنا مش عايز القضية دي بقى . \n\n### Response:بسكويت من فضلك و بعد ذلك أنا لا أريد هذه القضية.'}],
#  [{'generated_text': 'Input:\nأنا معنديش مانع نحط إيدينا في إيدين بعض بس مش لازم يبقى حد في الصورة غيري. \n\n### Response:أنا معترض على وضع اليد في أيدي البعض ولكن ليس من الضروري أن يكون شخصاً في الصورة.'}],
#  [{'generated_text': 'Input:\nهنقضي اليوم تهاني، رفقي بعد إذنك بلغ السكرتارية تمنع أي تليفونات لحد ما نخلص الاجتماع و نشوف كل واحد عمل ايه في اللي كلفناه بيه.\n\n### Response:سنقضي اليوم في احتفال ، من فضلك أبلغ سكرتارية الاجتماع عن أي مكالمات تليفونية حدثت في ذلك اليوم.'}],
#  [{'generated_text': 'Input:\nلأن الأيام اللي جايه صعبة صعبة قوي أنا مش بخّوفك أنا بس بنبهك. \n\n### Response:لأنه ليس من السهل أبداً جداً على أي شخص أن يقوم بذلك.'}],
#  [{'generated_text': 'Input:\nو إن شاء الله بعون الله لما صحة الوالد كده تتحسن إحنا لينا زيارة خصوصي إن شاء الله.\n\n### Response:حسناً ، شكراً جزيلاً.'}],
#  [{'generated_text': 'Input:\nاومال ايه الحزن اللي في عنيك ده و ليه صوتك مخنوق بالشكل ده؟ \n\n### Response:هل لك أن تحجز لي مقعداً في قطار سريع ؟'}],
#  [{'generated_text': 'Input:\n العرايس الزيك يقعدوا مرتاحين و الدنيا كلها تخدمهم, ولا انتي عايزة تسرقي الأضواء مني أنا و عمك سعد الليلة دي\n\n### Response:الزوجان سعيدان جداً بهذا الزفاف ، ويسعيان جاهدين لقضاء أسعد الأوقات معاً.'}],
#  [{'generated_text': 'Input:\nالممثلين لما بيبقوا صحاب مع فريق العمل طبعاً مكان التصوير بيبقى مختلف تماماً تعالوا نشوف مع بعض الصحاب اللي بيمثلوا مع بعض و بيشتغلوا مع بعض بيعملوا ايه في بعض. \n\n### Response:الممثلون عندما يشاهدون فيلماً جيداً مع فريق عمل الفيلم غالباً ما يكونون أصدقاء جيدين. مكان تصوير الفيلم سيكون مختلفاً عما هو عليه في الفيلم نفسه.'}],
#  [{'generated_text': 'Input:\nباشا ديماَ على حق و بعدين في تاجر جملة جاي دلوقتي يستلم و يكّيش و المفروض تبقى انت و الزكي باشا موجودين عشان تاخدوا حقكوا.\n\n### Response:أود أن أحجز جناحاً صغيراً ، من فضلك.'}],
#  [{'generated_text': 'Input:\nتفتكر اني هقف هنا بالليل و الحرس بتاعكم يحقق معايا عشان أهزر معاك؟\n\n### Response:هل تعتقد أني سأقف هنا في الليل ؟'}],
#  [{'generated_text': 'Input:\nمفيش حد في الحته ميعرفش انك محامي بس مع ايقاف التنفيس. \n\n### Response:لا يوجد أحد في هذه الحههه يعرف أنك محتكسة للتنفس. '}],
#  [{'generated_text': 'Input:\nيا جماعة المسألة بسيطة جداً كلها شوية تربيزتين على مفرشين على كوبيتين. \n\n### Response:حسناً.'}],
#  [{'generated_text': 'Input:\nاه بس متتأخرش عشان تلحق بسرعة و خد بالك من السوق السودة بيبعوا التذكرة بخمسة جنيه حرمية خد بالك.\n\n### Response:حسناً ، سيدي. هل يمكنك أن تخبرني عن سعر التذكرة بخمسة عشر جنيهاً حراماً من فضلك ؟'}],
#  [{'generated_text': 'Input:\nعشان يحاربوا أي واحد يرشح نفسه قصادك في الدايرة حتى لو كان المرشح ده واحد ست في أول تجربة ليها و ملهاش هدف غير انها تساعد الناس الغلابة بجد. \n\n### Response:من فضلك أعطني تقريراً عن حالة الطقس غداً صباحاً.'}],
#  [{'generated_text': 'Input:\nايه الهبل ده انت اهبل خمسومية ايه و تلتومية ايه ازاي يعني؟ \n\n### Response:ما هو هذا الهزل من فضلك ؟'}],
#  [{'generated_text': 'Input:\nده تقصد يعني الشراكة القديمة اللي كانت بيني و بينك، و لا الشراكة الجديدة اللي كلمني عنها صفوت؟\n\n### Response:هل هذه هي المرة الأولى لك التي تتحدث فيها إلى شخص ما ، من فضلك ؟'}],
#  [{'generated_text': 'Input:\nلكن الظروف اللي حصلت و لما عرفت بخبر حسام الله يرحمه. \n\n### Response:لكن الأمر الذي حدث عندما علمت أن حسام الله يرعاه قد رحل هو أيضاً.'}],
#  [{'generated_text': 'Input:\nمش عايز لغبطة و لا تسرع علشان مننزلش على فشوش زي المرة اللي فاتت، اعترافات، أدلة متخرش الميه و من غير ما حد يمد ايده عليه. \n\n### Response:لا أريد أن أؤذي أحداً في منزلي.'}],
#  [{'generated_text': 'Input:\nمئة جنيه ايه؟ خلي المئة جنيه معاكي امسكي دي الوصية بتاعتي وصيتي.\n\n### Response:مائة جنيه ؟ من فضلك احتفظ بهذه المائة في محفظتي.'}],
#  [{'generated_text': 'Input:\nيا نهار مش فايت أنا اصطبحت بوش مين النهاردة طب بقولك ايه؟ أي أخبار جديدة اديني خبر بيها علي طول مع السلامة يا خويا. \n\n### Response:هل هذه هي المحطة التالية ؟ أي شيء آخراً ؟ هل تود أن تخبرني عن شيء ما ؟'}],
#  [{'generated_text': 'Input:\nو اتكلم مع دكتور هنداوي و أكد له انه هو في زيارة ودية لقصر سعد بيه و تقدر سعادتك تتصل بالسيد مدير الأمن و تتأكد من المعلومات دي. \n\n### Response:أبحث عن طبيب ماهر يتحدث الإنجليزية ويسمع جيداً إلى ما يقوله السيد مدير الأمن. هل يمكنك أن تخبرني عن ذلك السيد المدير ؟'}],
#  [{'generated_text': 'Input:\nو عارف تحركاته بالسم عشان كده بقولك اللي انت ناوي تعمله ده انتحار. \n\n### Response:أنا لا أعرف شيئاً عن هذه الرحلة الجوية.'}],
#  [{'generated_text': 'Input:\nهنقّسم الاختصاصات علينا كلنا لغاية أبوك لما يقوم بالسلامة ابقى عدي على المجموعة شوفها ماشيه ازاي؟\n\n### Response:سنقسمها إلى الأقسام التالية :\n(أ ، ب ، ج ، د ، ه ، ي ، ل ، جز ، ز) من فضلك.'}],
#  [{'generated_text': 'Input:\nيا سلام ده الواحد كان، الله ايه ده  الواحد ميعرفش يتهنى في الحمام شوية الله تعبان سبني اقعد شوية!\n\n### Response:يا سلام هذا الواحد كان ، يا له من واحد لا يعرف التهادي في الحمام كثيراًً جداً.'}],
#  [{'generated_text': 'Input:\nليه في ايه؟ هو مفيش قانون في البلد؟ خلاص تاهت و لاقيناها أبو النجا يقعد معاه و يتصرف هو مش محامي؟\n\n### Response:لماذا لا يوجد أي نظام في البلد ؟ هلا احتفظنا بحقائبنا كما هي ؟'}],
#  [{'generated_text': 'Input:\nحتى لو سعد الدالي حط عينه على المشروع ده احنا برضو اللي هناخده. \n\n### Response:أنا آسف ، لكن هل من الممكن أن تخبرني عن كيفية الوصول إلى هذا المكان ؟'}],
#  [{'generated_text': 'Input:\nلأن هاني قالي ان المهندس جاسم مسنود و مش هيعدي الموضوع ببساطة. \n\n### Response:من فضلك أخبرني عندما نصل إلى المطار.'}],
#  [{'generated_text': 'Input:\nأهو يا سيدي اتفضل ابقى خليه ياكل في البيت كويس جداً لانه خلصّلنا كل الشباشب و الملايات و المراتب و كل حاجة و أقولك على حاجة متنيموش جمب معيز يلا.\n\n### Response:هل من الممكن أن تخبرني كيف أصل إلى هناك من فضلك ؟'}],
#  [{'generated_text': 'Input:\nانت أكيد مجنون، اسمع يا أدهم أنا جيت أنصحك أول ما شوفت الخبر منشور في الجريدة.\n\n### Response:أنت بالتأكيد غبي ، اسمع يا سيدي لقد نصحتك من أول نظرة عندما رأيت الخبر المنشور في الجريدة.'}],
#  [{'generated_text': 'Input:\nليه يا باشا هو اللي أنا شوفته في القصر ده كان سراب و لا ايه؟ اذا كان سيادتك بكل هيلمانك روحت لغاية عنده في القصر و مش عايزني أنا أقلق؟ \n\n### Response:لماذا يا سيدي ؟ إنه المكان الذي رأيت فيه سراباً في هذا المكان. هل يمكنك أن تخبرني عن سرعتك في ذلك المكان ؟'}],
#  [{'generated_text': 'Input:\nأيوه! لو بلغنا البوليس هيجوا يقبض عليه، و هنطلع من المولد بلا حمص!\n\n### Response:نعم ، سنأتي في الحال.'}],
#  [{'generated_text': 'Input:\nولا حظي مره بان وطلعلي في اللبان انا قولت الدنيا ضحكت والحظ اوانه حان اترايه ياناس منابي عريان نايم جعان مش لاقي لقمه ياكلها ويبندغ في اللبان، وانت\n\n### Response:أنا من اليمن.'}],
#  [{'generated_text': 'Input:\nعموماً أنا لازم أتحرك بدري عشان عندي مواعيد في الوزارة بعد الظهر.\n\n### Response:أود أن أحجز غرفة بسريرين في السابعة صباحاً ، من فضلك.'}],
#  [{'generated_text': 'Input:\nيادي الفال اللي مش زي بعضه روح يا سيدي ربنا يكرم أصلك.\n\n### Response:أنا آسف. ولكن من فضلك لا بد أن تحضر إلى غرفتك أولاً.'}],
#  [{'generated_text': 'Input:\nهما دول بقى اللي شربوا مشروع الصالحية بس كان مغرز ايه يا بسومه مغرز على كيف كيفك اهم تلاقيهم يا عيني جايين دلوقتي عشان يعوضوا خسارتهم. \n\n### Response:هذا هو بالضبط ما كان يجب أن يكون عليه الأمر بالنسبة إلى ميستورا ، أليس كذلك ؟'}],
#  [{'generated_text': 'Input:\nبسبوسة باللوز و الجوز و المكسرات و المدغدغات ..انا كريم كريم كرمله كركوكه\n\n### Response:بسكويت بالشيكولاته و رقائق البطاطس و السجق المحمص, من فضلك.'}],
#  [{'generated_text': 'Input:\nعداك العيب يا معلمي، هي بسبوسة عشان لو حد من الملاكمين وقع على الحلبة و لازق بسبوسة تقومه على طول.\n\n### Response:هل يمكنك أن تخبرني كيف أتحكم في مشاعري ، من فضلك ؟'}],
#  [{'generated_text': 'Input:\nالا بالحق يا خالد هي ايه الحركات اللي كنت بتعملها فوق اللي ضحكت بابي قوي كده ما تضحكونا معاكوا؟ \n\n### Response:أرجو المعذرة يا سيدي. هل من الممكن أن تخبرني عن بعض الحركات التي كنت أقوم بها فوق تلك التي ضحكت بها ؟'}],
#  [{'generated_text': 'Input:\nجبتوا الولد ليه أنا مش قولت نوال بس حرام ولد أمور زي ده يشوف اللي هيحصل. \n\n### Response:لقد أحضرت إبريقاً من الخزف من فضلك.'}],
#  [{'generated_text': 'Input:\nعمر سعادتك شوفت عهدة تدخل مخزن لا على صادر و لا علي وارد؟ \n\n### Response:هل من الممكن أن تخبرني كيف أصل إلى محطة السكة الحديدية ؟'}],
#  [{'generated_text': 'Input:\nيلاّ يا كفته بسرعة أنا عايز مراية و عايز كرسي و حاجات من دي عشان المكياج بتاع المدام و ناس بتفهم خلي بالك. \n\n### Response:من فضلك أعطني إيصالاً لشركة التأمين الخاصة بي.'}],
#  [{'generated_text': 'Input:\nهي الدماغ شغالة اه مية مية بس مركز قوي و حياتك عيب يا رفقي ده أنا فوزي الدالي تحب نتكلم في عربيتك و لا عربيتي و لا في الحديقة؟\n\n### Response:هل من الممكن أن تخبرني عن رقم تليفونك وعنوانك وعنوان بريدك الألكتروني وعنوان عملك وعنوان إقامتك وعنوان شركتك وعنوانه البريدي ؟'}],
#  [{'generated_text': 'Input:\nبالراحة عليه يا فوزي مش كده كفاية اللي هو فيه.\n\n### Response:بالراحة عليها يا سيدي. هل لي أن أراك مرة أخري ؟'}],
#  [{'generated_text': 'Input:\nحاولنا نلم خالد من غير ما نقولك عشان انت تركز في الأهم ايوا ، سعد انت نسيت اللي حصل لألفت مع دكتور هنداوي و غيره و غيره!\n\n### Response:حاولنا أن نلمك من غير أن تقول أي شيء لك حتى لا تزعجك في الأغلب.'}],
#  [{'generated_text': 'Input:\nلانه لاقى أوضة مؤنس مليانه من الأرض للسقف بصور مدام سعاد.\n\n### Response:إنه لأمر محزن حقاً أن أرى هذه الغرفة مؤثً جداً من الداخل.'}],
#  [{'generated_text': 'Input:\nلا مشكر مش عايز أشرب حاجة، أنا مش جاي أضايف، أنا جاي أعرف ايه اللي بيحصل؟\n\n### Response:لا أريد أن أشرب شيئاً ، أريد أن أعرف ما الذي يحدث ؟'}],
#  [{'generated_text': 'Input:\nمعلش، إنتي أول مره تنكسري فيها؟ معلش، إن شاء الله كده هيفوقوا. إلا المهم قوليلي، في حد عجبك فيهم؟\n\n### Response:حسناً.'}],
#  [{'generated_text': 'Input:\nايوا حنبتدي التقطيم بقى في ايه يا فوزي؟ هو انت كل ما تلاقي نفسك فاضي تقول أجيب صفوت عشان أنكد عليه؟ \n\n### Response:أيها تفضل التقطيم الآن يا فوزي ؟ هو أنت كل ما تجد نفسك في حيرة من أن تقول له شيئاً لكي ينكد عليك ؟'}],
#  [{'generated_text': 'Input:\nأنا يا فندم مؤهلاتي بكالريوس تجارة جامعة المحيطات دي جامعة متخصصة لوحدها و مدفعتش مصاريف أخر سنه و أعزب. \n\n### Response:أنا يا سيدي حاصل على بكالوريوس في إدارة الأعمال من جامعة '}],
#  [{'generated_text': 'Input:\nو أنا سمحتلك لو لو لاقتني داخل في الغلط ده تلفت نظري. \n\n### Response:أنا مسرور بلقائك.'}],
#  [{'generated_text': 'Input:\nلو وصلت لأي معلومة عن اللي دبروا الحادثة أو ارتكبوا الجريمة قبل رجالتنا هنا في الوزارة حتبلغنا؟ \n\n### Response:من فضلك سجل اسمك وعنوانك ورقم تليفونك وعنوان البريد الإلكتروني الخاص بك في سجلاتنا.'}],
#  [{'generated_text': 'Input:\nقالولي ان عندك كلمتين عايز تقولهم ليا علشان تريح ضميرك، قولت أهلاً و سهلاً ، بس المهم انه ما يكونش كداب عشان ما نضيعش وقت بعض.\n\n### Response:قالوا لي أن لديكم الكثير من الكلمات التي تود أن تقولها لي ، من فضلك قل لي ما هي ؟ هل تريد أن تقول لي شيئاً ما ؟'}],
#  [{'generated_text': 'Input:\nيعني أيه؟ هبقى في المستشفى و مش هشوف سعد الدالي؟\n\n### Response:ما هي ؟ هل سأستقل القطار المتجه إلى المحطة التالية ؟'}],
#  [{'generated_text': 'Input:\nطب بس من غير عصيبة، أنا فعلاً قولتلك وقتها وانت اللي قولتلي اتصرف، اتصرفت. \n\n### Response:حسناً ، من فضلك.'}],
#  [{'generated_text': 'Input:\nما ابا فندق أنا، مخدات لي فيها ريحة، لأن ما أقدر أرقد، إتيني حجة في ينبي، حساسية عندي\n\n### Response:لا أريد فندقاً أنا أيضاً ، لكنني أخشى أن لا أكون قادراً على الاستيقاظ مبكراً. هل لي أن أدعوك لزيارتي في أقرب وقت ممكن ؟'}],
#  [{'generated_text': 'Input:\nيا ولدي يا نيشان، شلك في البحر و اهواله و رزق الله عالسيف يا ابوي\n\n### Response:من فضلك سجل اسمك على طوابع البريد.'}],
#  [{'generated_text': 'Input:\nاشو أخاف، أنا لحد يطريلي الحنيش، أنا أنا أنا ملدوغ يوم إني صغير ، أنا حية لادغتني يوم أنا صغير، كنت أتمشى في السكة و يت حية جي و عفدت علي\n\n### Response:أنا آسف ، أخشى أن أكون لطيفاًً ، أنا لا أستطيع أن أغادر أبداً. من فضلك املأ حافظة نقودي بأقصى سرعة ممكنة.'}],
#  [{'generated_text': 'Input:\nصار له يومين ما سار الحفيز ما يقدر يقوم يقولون\n\n### Response:لقد فقدت محفظتي. من فضلك احتفظ بها في صندوق السيارة.'}],
#  [{'generated_text': 'Input:\nيا جماعة الخير، أنا عندي بشارتين لكم، ودي أبشركم بهن\n\n### Response:من فضلك ، من فضلكم ، هل لي أن أرى جواز سفري ؟'}],
#  [{'generated_text': 'Input:\nوا ابويه، ساعة ! تبانا نيلس في اللفت ساعة ! سير اتصل في المطافي\n\n### Response:أمي ، ساعة. ساعتان. سأتصل بها في الساعة الثالثة. شكراً جزيلاً.'}],
#  [{'generated_text': 'Input:\nاعتقد ان هناك عندهم انترنت كافيه، ما يحتاج تشلين اللابتوب وياج\n\n### Response:أعتقد أن هناك اتصالاً كافيا ، من فضلك.'}],
#  [{'generated_text': 'Input:\nالسنة الماضية أنا مودنها و مركبنها قطار الموت، و ما قالت شي، شحقه الحين مب طايعة و مسوية عمرها تخاف\n\n### Response:في العام الماضي ، كنت أركب قطار الموت ، ولم تقل شيئاً حتى الآن. هلا أخبرتني عن ذلك الآن ؟'}],
#  [{'generated_text': 'Input:\nمرحبا، هلا، عباس ما شاء الله و عايلته الكريمة، عند بابنا، يا مرحبا يا مرحبا، أهلًا و سهلًا، تفضلوا\n\n### Response:هلاّ ، هلا ، يا سيدى ، هل من الممكن أن تخبرنى عن كيفية الوصول إلى الباب ، من فضلك ؟'}],
#  [{'generated_text': 'Input:\nما عليه، آمر آمر يا مطوعنا ضاعن، ما يهمك قول\n\n### Response:هل من الممكن أن تخبرني إذا كان بإمكانك مساعدتي في العثور على مكان إقامتي ، من فضلك ؟'}],
#  [{'generated_text': 'Input:\nأنا تقوليلي خسك الله عشان يبت موسيقى؟ ميثة، ميثة، أرجوج تفاهمي ويا يدتج، لا ابوج لا ابو يدتج\n\n### Response:هل من الممكن أن تخبرني عن خسك في الموسيقى ؟ هل توجد أية حفلة موسيقية أخري ؟'}],
#  [{'generated_text': 'Input:\nلا يا امي يزاج الله خير، يزاج الله خير، ما تقصرين، بسير أحط راسي شوي و برقد، و إن شاءالله بطيب\n\n### Response:لا يا أمي ، لقد رزّّ الخير ، أليس كذلك ؟'}],
#  [{'generated_text': 'Input:\nشوفي ويهج فالمنظرة، هاه تبغين نسويلج بوتيكس و لا ما نسويلج بوتيكس\n\n### Response:من فضلك افتح فمك قليلاً. هلا فتحت فمك كثيراً من فضلك ؟'}],
#  [{'generated_text': 'Input:\nوالله العظيم ما لينا يلسة في هالبيت أقولش، هذي حلفة، اتصليبهم و الا حرام ترى لا اضربش بهالهمبا على عينش، اتصلي أقولش\n\n### Response:حسناً ، شكراً جزيلاً.'}],
#  [{'generated_text': 'Input:\nو الله جنج إنتي بخبرج يالسة تجذبيني،  بروحه أقولج ياني، و قالي جوفي سيري و انشدي أمي و جان هي موافقة أنا ما عندي أي خلاف\n\n### Response:حسناً.'}],
#  [{'generated_text': 'Input:\nبعد رد يقول ليش يجذبوني، شقى نصدقك و أنا تحت إيدي شاهد حاضر و شايف\n\n### Response:من فضلك احتفظ بالباقي في صندوق السيارة.'}],
#  [{'generated_text': 'Input:\nإنزين عاد شخانته ألحين العرس يوم ما شي فيه عيالة و لا فيه رزفه و لا اشو هذا الأغاني الي يحطون الناس يا ابويه تخبلوا\n\n### Response:حسناً.'}],
#  [{'generated_text': 'Input:\nإنت ما كنت موجود في البلاد و لا تدري شو يصير، أنا و مرزم يا ما ساعدنا ناس\n\n### Response:لم أكن موجوداً في البلاد منذ عشر سنوات ولا تعلم ماذا تفعل ، أنا و مزمار مسجلان في سجلاتنا يا سيدي.'}],
#  [{'generated_text': 'Input:\nلا تشره على أبوك، محد في البلاد راضي إن عيد ياخذ حصة\n\n### Response:لا تذهب إلى والديك ، لا أحد في البلاد يريد أن يحتفل بعيد رأس السنة.'}],
#  [{'generated_text': 'Input:\n كان المفروض أحضر شهود يوم يستلم مني اللولو، جان ما طبيت بهالمشكلة أبدا، أنتوا تحمون الظالم \n\n### Response:كان المفروض أن أحضر إلى متجر '}],
#  [{'generated_text': 'Input:\nأرجوج، إسكتي و اصبري خلينا نفهم السالفة، أنا عندي موضوع جوهري، خليني بناقشه ويا الحرمة، أرجوج، يعني إنتي ألحين، عايبنج كلام ولدج ؟\n\n### Response:أرجوك ، اصبري قليلاً ، من فضلك.'}],
#  [{'generated_text': 'Input:\nيابوك ، اليوم تقدر تسوي خير في الناس، خير جثير، و تدفع عليه دراهم جثيرة، لكن الناس ما يملى عيونها أي شي، مادري، مادري ليش\n\n### Response:أود أن أستأجر سيارة أجرة من أجل الذهاب إلى العمل ، من فضلك.'}],
#  [{'generated_text': 'Input:\nوالله يا عبيدان بتعرس، إذا ياك ولد شو بتسميه؟ بسميه طعان \n\n### Response:حسناً.'}],
#  [{'generated_text': 'Input:\nبيي باجر، يا أنا يا هي، و أنا براويها منو بنت غريب، يلا تصبح على خير\n\n### Response:سأغادر غداً ، يا سيدي ، شكراً جزيلاً لك.'}],
#  [{'generated_text': 'Input:\nهلا، هلا باللي لفانا يا هلا به، هلا، هلا بالغزال إلي شايل في بطنه أسد\n\n### Response:هلاّ ، هلا بمن لف على كتفنا يا هذا ، لقد لف على بطنك أسد.'}],
#  [{'generated_text': 'Input:\nأوهو يدوه، خلاص فكينا من هالبراقع، قتلج لبسي نقاب، نقاب، ابوي\n\n### Response:أوه ، إنه يكفينا جميعاً ، سنقتلع ملابسنا ، نقابنا ، من فضلك.'}],
#  [{'generated_text': 'Input:\nيابوي انتي بلاج سايرة رادة رادة سايرة تراه عورتي راسي\n\n### Response:هل يمكنك أن تخبرني كيف أتحكم في درجة حرارة الغرفة ؟'}],
#  [{'generated_text': 'Input:\nيا غريب الله يهداك هذي مب حقي بروحي ترا حق بناتك بعد\n\n### Response:يا غريب هل لك أن تساعدني في العثور على حقيبتي ؟'}],
#  [{'generated_text': 'Input:\nبخير الحمد لله، خير يا هلال ؟ يقولون تبوني إنتو\n\n### Response:بخير يا هلال ، شكراً على دعوتك لي.'}],
#  [{'generated_text': 'Input:\nما قلت لك يا أخ زيد إن المال الحلال ما يضيع؟\n\n### Response:هل أخبرتني يا سيدي عن المال الحلال ؟'}],
#  [{'generated_text': 'Input:\nوش تقصد يا راجح، يعني أخوي خلاص، اندفن تحت التراب راح؟\n\n### Response:هل لك أن تدلني على أي طريق يؤدي إلى هذا الطريق ، من فضلك ؟'}],
#  [{'generated_text': 'Input:\nوابوك يالأبو حلاق يديد فالبلاد؟ هه ياسمينا، ياسمينا، يود يود\n\n### Response:هل لك أن تزكي لي هدية من فضلك ؟ سيدينا ، السيدينا ، سيدينا, سيدينا.'}],
#  [{'generated_text': 'Input:\nوين وين أنا أدرسهم يا مطوع، حد يدرس هذيله و إنت موجود في البلاد؟\n\n### Response:أين يمكنني أن أستقل حافلة لنقل الطلاب من فضلك ؟'}],
#  [{'generated_text': 'Input:\nإيه اندوك غريب، لا يا أبويه مب سايرة عندهم و لا شيات، على قولتك سهيل و عبيد هم الي يون عندي هني\n\n### Response:إنه غريب جداً ، لا يا سيدي ؟ لقد غادرت للتو من مكان الحادث.'}],
#  [{'generated_text': 'Input:\nوحليلها أمها تعبانة بعد، أبوي غريب، البنية أظني فيها غازات قوم إيبلها ماي غريب\n\n### Response:إنها تؤلم كثيراً جداً في معدتها ، من فضلك.'}],
#  [{'generated_text': 'Input:\nيا اخوي ما سوينا شي، لا دق، لا رقص، لا غنة، لا مسجل و لا تلفزيون، مبندين كل شي، ها تسمع بروحك تبغي تدخل تفضل\n\n### Response:يا سيدي لا نفعل شيئاً ، لا نفعل أي شيء ، لا نأكل ، لا نشرب ، لا نلعب ، لا نتناول أي طعام.'}],
#  [{'generated_text': 'Input:\nزين زين يوم يشغلون المواطنين في البنوك، عشان يساعدوني أنا و أمثالي\n\n### Response:حسناً ، شكراً جزيلاً.'}],
#  [{'generated_text': 'Input:\nبس هي ما تخبر حد، عندها أربعين ألف سهم إتصالات\n\n### Response:ولكنها لا تخبر أحداً ، عندها أربعين ألفاً من أسهم شركة الاتصالات.'}],
#  [{'generated_text': 'Input:\nآمنة امي، سيري هاتيلي في الملة تراب، البلغم زايد عليه\n\n### Response:آمنة أمي ، شكراً على دعوتك لي.'}],
#  [{'generated_text': 'Input:\nيوم إلا هذا الذوق، مب عايبنكم، شحقه ما تسيرين انتي و ريلج تشترون حق بنتكم، ليش تدخلوني أنا بمشاكلكم و بلاويكم، دريول أبوج أنا ؟، هاتي هاتي\n\n### Response:هذا يوم آخر ذوق ، أليس كذلك ؟ هل لك أن تزكيها لي ؟ هلا تزكيتها أنا أيضاً ؟'}],
#  [{'generated_text': 'Input:\nوابويه، جان بق البيت علينا ألحينه و احترقنا، عافانا الله يا هالخدية الحرمة دومها خدية\n\n### Response:أوه يا سيدي ، لقد احترق المنزل علينا كثيراً منذ زمن بعيد جداً. شكراً جزيلاً على كرم ضيافتك.'}],
#  [{'generated_text': 'Input:\nأظن إن القيادة بتطلع منك الجواب، راجح عطاك ليونة أزيد عن اللازم، إخذه يا راجح\n\n### Response:أظن أن القيادة سوف تخرج منك الإجابة الصحيحة ، من فضلك أعطني مزيداً من الوقت.'}],
#  [{'generated_text': 'Input:\nأنا وين عندي حشرة ؟ ! إنت رطين أنا أسمع رطين ما ادري، عندكم ناس ضيوف شي\n\n### Response:أين يمكنني أن أجد شيئاً من هذا القبيل ؟'}],
#  [{'generated_text': 'Input:\nانت إيه، كل عيوز تشوفها تقول كيه أمه ويش؟ هذي يدة حرمته ضبابة\n\n### Response:ماذا تعني كل من هذه ؟ إنها تذاع على الهواء مباشرة من خلال سماعات الأذن. هل هذا يعني أنها تذاع من خلال السماعات ؟'}],
#  [{'generated_text': 'Input:\nيدوه، العلم تطور الحينه، مب شرات قبل، يشوفون الياهل في الكيمرا، لا تسيرين تزيغينها برمسة قبل\n\n### Response:يديه ، من فضلك.'}],
#  [{'generated_text': 'Input:\nصدق أمايه، إنتو شحقه رديتوا، المفروض أحين تكونون داخل خن الطيارة، أجوفكم رديتوا\n\n### Response:إنها في طريقها إلى المطار ، من فضلك.'}],
#  [{'generated_text': 'Input:\nيعني أنا الليلة بس يالس أشتغل عندكم و عند هاي الصغيروني\n\n### Response:هل من الممكن أن تخبرني كيف يمكنني أن أقوم بعمل ذلك ؟'}],
#  [{'generated_text': 'Input:\nمصختها تراك يا عيد مصختها، اسمعني، انته أكبر مشكلة في البلاد، الزم حدودك من فضلك\n\n### Response:مصباحها يجعلها تبدو أكبر حجماً ، اسمعني ، إنها أكبر مشكلة على الإطلاق في البلاد. ألتزم حدودك.'}],
#  [{'generated_text': 'Input:\nغريب، هذا غريب نسيبنا الي ماخذ إختنا ميثا، ما قمت تشوف شو ؟\n\n### Response:أنا آسف ، هذا غريب جداً أن نسافر إلى اليابان بمفردنا. هل يمكنك أن تخبرني كيف حالك ؟'}],
#  [{'generated_text': 'Input:\nاسمعني زين ما زين، ناس تيمع بيزات، تيمع طوابع، تيمع ذهب\n\n### Response:اسمعني جيداً ، شكراً جزيلاً.'}],
#  [{'generated_text': 'Input:\nإن شاء الله يمعة خير و بركة إن شاء الله\n\n### Response:أشكرك جزيلاً لك على دعوتك لي.'}],
#  [{'generated_text': 'Input:\nإذا إنتي تجوفينها هذي غلطة صغيرة، أنا أشوفها غلطة عودة\n\n### Response:من فضلك أرني قائمة بالأشياء التي يجب أن لا تأكلها في اليوم التالي.'}],
#  [{'generated_text': 'Input:\nإنتي ما تستحين على ويهج، إنتي ما تستحين على ويهج؟ ما يخصج تسئلين وين نسير و نيي، مالج شغل تسئلين، إلبسي عباتج جدامي أشوف يلا، يلا بسرعة\n\n### Response:أنت لا تستحمين على ياجوج وماجوج ؟ هل لك أن تسألين أين سنذهب ونلقي نظرة على الطريق ونطمئن على أنفسنا ؟'}],
#  [{'generated_text': 'Input:\nالشرهة مب عليك، إنت ما شفتني و أنا يالسة أحاول أشوف حد يشتري البيانو في العمارة، واحد منهم تعرف شو قالي ؟\n\n### Response:من فضلك سجل اسمك وعنوانك ورقم غرفتك.'}],
#  [{'generated_text': 'Input:\nالمشكلة يا عمي، إن راجح مب طايع يصدق إن نايف كان ويايه أنا ويا مفتاح عالسيف يوم انجتل عيد\n\n### Response:لا يوجد مشكلة يا سيدي ، إنه ماهر حقاً.'}],
#  [{'generated_text': 'Input:\nو الله، و الله يا عمي ها، نذرا علي ها، إذا عطيتني المتوه، لمدة شهر شهر كامل بعطيك ماي بلاش، و لا ليش شهر، سنة كاملة يا عمي\n\n### Response:حسناً.'}],
#  [{'generated_text': 'Input:\nاشو انتقاد و إيجابية و أمر واقع شو هالكلام الكبير هذا وين، شفهمها في هالسوالف، قوليلها إنتي ما يخصج و خلاص  \n\n### Response:أرجو المعذرة على هذا الخطأ غير المقصود.'}],
#  [{'generated_text': 'Input:\nأنا يا بنيتيه، حيث إنه ريولي عورتني من كثر اليلسة\n\n### Response:هل يمكنك أن تخبرني كيف أستطيع أن أتحكم في درجة حرارة الغرفة من فضلك ؟'}],
#  [{'generated_text': 'Input:\nشحقه طبيب ؟ شحقه طبيب البنت فيها غازات ما يحتاج طبيب !\n\n### Response:مقاس كبير ، من فضلك.'}],
#  [{'generated_text': 'Input:\nهذا و إنت موظف و درجتك أربعة اثنين، و مسوي هالحشرة كلها، بخبرك لو مدير شو بتسوي ؟ سير سير و فكنا من لغوتك، اجتماع و اجتماع، تقول اجتماع مجلس الأمن \n\n### Response:هذا و أنت موظف و لديك درجاتك أربعة اثنان اثنان ، و وظيفتك هي أربعة اثنين اثنان ، ماذا ستفعل ؟ سوف تخبر مديرك بكل شيء ؟'}],
#  [{'generated_text': 'Input:\nأنا ما قلتلكم ودوها عندكم يلسوها هناك عشرين يوم، شحقه رادين بعد يومين شحقه ؟\n\n### Response:لم أقلقكم كثيراًً الليلة الماضية. هل تودون إعادتها غداً صباحاً ؟'}],
#  [{'generated_text': 'Input:\nخلي البنت يابوي خلي البنت على راحتها خله تجوف شو شغلها شتبين بها، خليها مسكينة \n\n### Response:أعطني واحداً من فضلك.'}],
#  [{'generated_text': 'Input:\nأبوي، أنا صح قلت له أبغي الفستان فيه الكسرات هذي، بس ما قلت هالوسع، و بعدين رقبته مو سبعة ما ابغي، شو ها راعي الخياط ما يفهم؟\n\n### Response:أنا ، يا سيدي ، قلت له أريد فستاناً ضيقاً من فضلك ، أليس كذلك ؟'}],
#  [{'generated_text': 'Input:\nأشوف عيونج نطت برا، وين إلي تقول دراستي و الشهادة ؟\n\n### Response:أراهن على صوتك ، من فضلك.'}],
#  [{'generated_text': 'Input:\nيا عبيدان، يا عبيدان أنا و أنت مسؤولين عن غلطات الجماعة، و شو بنقولهم القيادة إذا سئلونا أنا محرج\n\n### Response:أهلا ، شكراً جزيلاً.'}],
#  [{'generated_text': 'Input:\nهذا زين يسويلك زيادة دم في القلب، و ينشطلك القلب يحركه تحريك هيه\n\n### Response:هذا جيد جداً ، ويسعك أن تكون أكثر نشاطاً في العمل.'}],
#  [{'generated_text': 'Input:\nو قالوا إن حارب هو آخر واحد خذ السجين، و بعدها ما شفنا السجين\n\n### Response:أخبرهم أن الحرب هي آخر شيء يفكرون فيه بعد إلقاء القبض عليهم. ثم أخبرهم أن هذه هي آخر مرة ألقي عليهم فيها القبض.'}],
#  [{'generated_text': 'Input:\nأنا أعرف و الجماعة كلهم الحاضرين يعرفون إن بومحمد ما سرق منه شي\n\n### Response:أنا أعرف جميعاً من هو السيد بومًمباً الذي سرق منه شيئاً كبيراً.'}],
#  [{'generated_text': 'Input:\nهذا ولد ناس و ولد عرب، أنا روحي تخبرت عنه، و قالوا لي إنه ريال و محترم و رزين بعد\n\n### Response:هذا ولد أناس و ولد عربي ، أنا ذهبت لرؤيته ، وقالوا لي إنه شخص ناضج و طيب و ذو شخصية قوية.'}],
#  [{'generated_text': 'Input:\nالعيايز اخترعوا هاي السالفة، علشان الصغارية، يخوفونهم، يكون ما يطلعون الظهر، القايلة لا، ما يطلعون\n\n### Response:من فضلك اختر لوناً آخر ، من فضلك.'}],
#  [{'generated_text': 'Input:\nعاد الحجاج، قاله يا يا عجوز، انته ألحينه بتنتظر لين ما تاكل هذي الثمرة\n\n### Response:هل من الممكن أن تخبرني كيف يمكنني أن أتناول هذه الفاكهة ؟'}],
#  [{'generated_text': 'Input:\nخله يولي، هذا كله مغربلنا و لا مبهدلنا، ما يشبع، و بعدين ليش خايفين ؟ الي حضر البيعة المطوع ضاعن\n\n### Response:دعه يخرج ، من فضلك.'}],
#  [{'generated_text': 'Input:\nاحنا جي ولا جي الليلة بنبات برا، شرايك الليلة نبات فاتلانتس، و باجر من الصبح نسير الفجيرة\n\n### Response:نحن نأكل كثيراً جداً في الليلة الواحدة ، من فضلك.'}],
#  [{'generated_text': 'Input:\nعاد قلت يدو العالم ما شاء الله ههه يايبيلج هالهدايا و يايبيلج هاي الكراتين\n\n### Response:هل من الممكن أن تخبرني عن هذه الكراتين ؟'}],
#  [{'generated_text': 'Input:\nما عليه سامحيني، سامحيني يا ميثا سامحيني، إنتي أكثر وحدة تعرفين الظروف إلي أنا أمر فيها، ريال، راعي حلال، ولد عز، عايش بنعمة و خير، مرة وحدة أرهن بيتي و مزرعتي و أرضي و كل حلالي، و الأسهم تدق دقة وحدة، و كل هالامور هذي تروح عني و أسكن في هالشقة هذي أنا و عيالي، صعبة صعبة، لا و أنا بعد استعيلت و سرت\n\n### Response:من فضلك, املأ هذه الاستمارة ، اسمك وعنوانك ورقم بطاقتك الائتمانية وعنوان عملك وعنوان إقامتك وعنوان جواز السفر وعنوان البريد الإلكتروني الخاص بك ، من فضلك.'}],
#  [{'generated_text': 'Input:\nسمعيتها ؟ سمعتيها كيف تتكلم و شقايل تسوي ؟ أحين بخبرج هذي المفروض تتصلين بأهلها، ولي أمرها يي، و لا تراها ما بترد الصف و هي لسانها أطول منها\n\n### Response:هل من الممكن أن تخبرني كيف تتحدثان وكيف تسعاً ، من فضلك ؟ هلا اتصلت بأهلها ، ولي أمرهما يقولان كلاماً حسناً.'}],
#  [{'generated_text': 'Input:\nأما أنا ريال ولد عز، أنا راعي كرامة، أنا ريال شايف خير، عندي أسهم لو إنهن داقة لكن عندي أسهم، مب أنا ياي محتاج حق كراتينك معجون طمام ما ادري صابون فودر، يلا تصبح على خير\n\n### Response:فقدت حقيبتي.'}],
#  [{'generated_text': 'Input:\nعظم الله أجرج يا بنتي ادخلي داخل ادخلي داخل وقولي لا حول ولا قوة إلا بالله\n\n### Response:آسف. اسمح لي أن أدعوك إلى الدخول من فضلك. هلا أخبرتني عن اسمك وعنوانك البريدي وعنوان البريد الإلكتروني الخاص بك ؟'}],
#  [{'generated_text': 'Input:\nأنا بعت بنتي ؟ أنا بعطيها حق ريال محترم يصونها و يقدرها\n\n### Response:هل من الممكن أن تخبرني عن كيفية الحصول على حقائبي ؟'}],
#  [{'generated_text': 'Input:\nو أنا عاد ها سايرة و هذا بعد حلول عطه غولي\n\n### Response:هل من الممكن أن تخبرني كيف أصل إلى هناك ؟'}],
#  [{'generated_text': 'Input:\nأدري و الله، و الله أدري، تصدق يا خوي، أنا ألحينه، ريحيتني أنا أحينه بسير دايركت حق الحلاق، أربع ساعات وفرت علي، بسير الحلاق ألحين  \n\n### Response:أظن ذلك ، يا سيدي ، أعرف ذلك. هل يمكنك أن تخبرني عن الحلاق ؟ أربع ساعات من الراحة ساعدتني على أن أصبح طبيباً مبتدئاً. لقد ساعدتني أيضاً على أن تصبح طبيبةً جيدة.'}],
#  [{'generated_text': 'Input:\nبارك الله فيك يا ولدي بارك الله فيك يا ولدي \n\n### Response:شكراً جزيلاً لك يا سيدي.'}],
#  [{'generated_text': 'Input:\nمتى بس أفتك من هالشقة هذي، متى بتخلص هالفلا، عنبو أربعة راقدين في حجرة\n\n### Response:متى سأفتك من هذه الشقة ، متى ستنتهي ؟'}],
#  [{'generated_text': 'Input:\nشعنه عاده كلام فاضي ؟ في أم ما تتمنى الخير حق بنتها ؟\n\n### Response:ما هي عادة يومية ؟ في أي وقت ترغب في أن تكون ؟'}],
#  [{'generated_text': 'Input:\nإذا عندنا حد مريض كلنا نوقف وياه لين الله يشافيه\n\n### Response:من فضلك أعطني تقريراً عن الحادث.'}],
#  [{'generated_text': 'Input:\nغريب، الشقق ما يستوي فيها شي، كل شي فيها يفوح\n\n### Response:إنه غريب حقاً ، لا توجد بها أي شقق. كل شيء فيها يطفو على سطح الماء.'}],
#  [{'generated_text': 'Input:\nلا لا لا، جذي أنا بكبر الموضوع يا جماعة أنا بكبر الموضوع\n\n### Response:لا لا ، لا أستطيع أن أتحمل هذا الأمر يا جماعة لقد كبرت المشكلة يا جماعاً.'}],
#  [{'generated_text': 'Input:\nأخذ الوقت اللي يكفيك يا راجح، المهمم تمسك لنا القاتل، و أنا ما راح أسامحه، يلا يا جماعة شننطر\n\n### Response:الوقت غير كاف تماماً لك يا سيدى, المهم أن نغادر جميعاً ، أليس كذلك ؟'}],
#  [{'generated_text': 'Input:\nإن حريم الحين كلهن اختربن، ما منهن فايدة، مب مثل حريم قبل، أنا أحيد أمي أول تنش الفير، و ما ترقد إلا على يوم الثاني عند أذان الفير\n\n### Response:إن نساء اليوم لا يفقهن شيئاً في أي شيء ، حتى أنهن لا يتحدثن كثيراً ، من فضلك.'}],
#  [{'generated_text': 'Input:\nأنا ما ابغي أعودها على على الراحة هيه، أباها تطلع من هذيل البنات إلي هب ريح، ما اباها تطلع من هالرخويات بارك الله فيش\n\n### Response:لا أريدها أن تعود أبداً على الراحة ، هي ها هنا. حسناً ، شكراً جزيلاً.'}],
#  [{'generated_text': 'Input:\nما شاء الله، إنتو شو عندكم، عرس و لا هو عيد ميلاد ؟\n\n### Response:حسناً ، هل لديكم حفل أم لا ؟'}],
#  [{'generated_text': 'Input:\nأول سبب إني أنا ممكن أخدم القضية من هني أكثر من القيادة\n\n### Response:أولاً أنني أستطيع خدمتكم من هنا أكثر من أي مكان آخر في العالم.'}],
#  [{'generated_text': 'Input:\nتهم، ما فيه شكر إشو جذي أخ لا مب غاوي \n\n### Response:لا شكراً شكراُ جزيلاً.'}],
#  [{'generated_text': 'Input:\nو أنا اللي كنت أظن انكم مستانسين بوجودي عندكم ترضون ترضون أقعد فالشقة بروحي و أنا في هالحالة لا حنيس ولا ونيس\n\n### Response:لقد ظننت أنكم لستم مستمتعين لوجودي بالقرب من مسكني الخاص. فأنا لا أستطيع أن أنسجم مع مشاعري وأحاسسي.'}],
#  [{'generated_text': 'Input:\nاي انتي ، شحقه تطريني ؟ انا شو يخصني في دانكم هذا\n\n### Response:أجل ، أنت ، من فضلك. هل لي أن أراك مرة أخري ؟'}],
#  [{'generated_text': 'Input:\nوشو اللي يثبت انه مصطفى ياب السجين حق بوأحمد الخياط؟\n\n### Response:ما الذي يثبت أن السيد مصطفى هو السيد المصاب بمرض مزمن ؟'}],
#  [{'generated_text': 'Input:\nيعني ألحين إنتي ما تعرفين شي عن سالفة الرضاعة ؟\n\n### Response:هل لك أن تخبرني كيف يمكنني أن أتثبت من حقيقة أن طفلي لا يرضع ؟'}],
#  [{'generated_text': 'Input:\nاسمع يا ربيعة ، خلك من هالسوالف هاي كلها ، ابغاك تاخذ ثلاثة أربعة صناديج مثلك جذه رجال وتمرون على عبيد وين ، المركز\n\n### Response:سمعت يا ԀՀՏանն '}],
#  [{'generated_text': 'Input:\nأبوي، تعرف، أنا و يمعة وايد وايد وايد انشغلنا في رمضان، و ما صار عندنا وقت نروح السوق و نشتري حق فاطمة، أبوي\n\n### Response:من فضلك, احتفظ بالباقي لك, من فضلك.'}],
#  [{'generated_text': 'Input:\nبعدين إنت تقولي أنا دربك خضر ؟ هاي آخرتها ؟ !\n\n### Response:هل من الممكن أن تخبرني كيف نصل إلى هناك ؟ هلا أخبرتني الطريق المستقيم ؟'}],
#  [{'generated_text': 'Input:\nهذا هادي و الهامل اللي معه اللي اسمه صبري بشتغلوا مع بعض شغل في كراج، أما شو شغل الله لا يورجيكِ! غشاشين\n\n### Response:هذا هو الهامل الذي يطلق عليه اسم '}],
#  [{'generated_text': 'Input:\nطيب ليش ما بيحكولنا إحنا مش أهل يعني؟! و لا نسيت يا حبيبي شو عملت عشان خاطرها! نسيت قديش ضحيت أنت على شان ما تحسسها إنها بحاجة لإشي!\n\n### Response:لماذا لا نحضر مائدة طعامنا نحن أيضاً ؟'}],
#  [{'generated_text': 'Input:\nاتفقنا هيك مع شركة على شغل و أنا يعني بدي أسافر يومين على العقبة بس يومين و بجوز اكثر ما بعرف بعدين أنا السبب في هاذي الصفقة\n\n### Response:لقد اتفقنا مع شركة أخرى على أن أقوم بالسفر يومين فقط. هل يمكنك أن تخبرني عن المدة التي ستستغرقها الرحلة ؟'}],
#  [{'generated_text': 'Input:\nطمنيني كيف نفسية عمو فرج؟ خصوصي بعد ما غاب يزن و ناجح عنه\n\n### Response:أخبرني كيف حالك أنت يا عم فرج ؟ خصوصي أن لا يغادر أبداً.'}],
#  [{'generated_text': 'Input:\nاصحى يا جودت و خلينا في اللي إحنا فيه، لا تخلي الرومنسية تنسيك الأهم\n\n### Response:سأصل متأخراً خمس عشرة دقيقة.'}],
#  [{'generated_text': 'Input:\nانا جاي اقول اللي شفته ولمسته وحسيته من هالرجل الطيب\n\n### Response:أنا قادم لأقول ما شعرت به ولمسته وأحسسته من هذا الرجل الطيب.'}],
#  [{'generated_text': 'Input:\nأبدًا، بكرة الصبح طلبيتك بتكون جاهزة، أنا رايح أوصل لك إياها بنفسي، إحنا بهمنا رضاك، و لا يهمك مع ألف سلامة\n\n### Response:أبداً ، غدا صباحاً موعداً لاستلام طلبك ، أنا ذاهب لأرسلها لك بنفسك ، لا تقلق مع ألف سلام.'}],
#  [{'generated_text': 'Input:\nاسمع أنت و إياه، بتشيلوا الغبرة اللي عالطاولة هاي مسحوها كويس، و بعدين كل الكاسات اللي لميتوهم هذول عالمجلى بسرعة\n\n### Response:اسمع اسمعاً واحداً ، من فضلك.'}],
#  [{'generated_text': 'Input:\nيابا يعني واضح من كلامه إنه مش هي اللي شجعته على الغلط\n\n### Response:كلاً ، إنه واضح تماماً من كلامه بأنه غير ناضج بما فيه الكفاية ليقرر ما الخطأ فيه.'}],
#  [{'generated_text': 'Input:\nناهده، الله يرضى عليكي أنا كنت واضح و صريح معك أرجوكي يا حبيبتي خلينا متفاهمين أنا ما كذبت عليكي بإي اشي\n\n### Response:هل من الممكن أن تخبرني عن مكان تواجدي الآن ؟'}],
#  [{'generated_text': 'Input:\nعارف، يا بني آدم، امسك زي الناس علقها يلا امسك\n\n### Response:أنا آسف ، يا بني, امسك هذه الأشياء يلاً امسك.'}],
#  [{'generated_text': 'Input:\nو البريكات اللي بتزيد عيارها ؟ و سلك البطارية اللي بتضعفه ؟ و صمونة مش عارف شو اللي بتخليها تنقط زيت و تحرق السيارة \n\n### Response:هل من الممكن أن أحصل على تذكرتين ذهاب وعودة إلى اليابان ؟'}],
#  [{'generated_text': 'Input:\nأشتري لك سيارة؟ ما شاء الله حولك و حوليك ليش بدك السيارة؟\n\n### Response:هل لي أن أشتري لي سيارة ؟ شكراً جزيلاً.'}],
#  [{'generated_text': 'Input:\nاتركوني عليها، يا دوب تتحمل مني مقلب واحد و بس\n\n### Response:من فضلك احتفظ بالباقي لي.'}],
#  [{'generated_text': 'Input:\nايش فيها يعني ايش فيها ايش فيها إذا عملك خاطر؟\n\n### Response:أي نوع من الطعام تحب أن تتناوله ؟'}],
#  [{'generated_text': 'Input:\nعن ازنك يا جارتنا هاظا جرس الباب برن مع السلامة، يلا يلا حاضر\n\n### Response:هل لك أن تريني قائمة طعامك غداً صباحاً ، من فضلك ؟'}],
#  [{'generated_text': 'Input:\nعاد كنت قاعد بكتب قصة مأساوية مؤلمة بعدين غيرت رأيي و قررت اكتب قصة كوميدية مضحكة من وحي الواقع\n\n### Response:لقد كنت أكتب القصص المضحكة بعد ذلك. قررت تغيير رأيي. قررت أن أكتب قصة مضحكة كوميديا من واقع الحياة.'}],
#  [{'generated_text': 'Input:\nما وقعت في مشكلة إلا و طلعت منها أقوى من أول، و رح أظل طول عمري هيك\n\n### Response:لم وقع في مشكلة منذ أول مرة وقعت فيها في المشاكل ، و سأظل دائما هيك.'}],
#  [{'generated_text': 'Input:\nعلى مهلك يا أم هاني الموضوع كله موضوع خطبة و يمكن ابطل ما بتعرفي \n\n### Response:هل من الممكن أن تخبرني كيف أصل إلى هناك ؟'}],
#  [{'generated_text': 'Input:\nو صعب ترجع و بكره بتشوف بس هي هي مجنونة هيك تركتهم ايد ورى وايد قدام حتى ذهباتها تركتهم هناك\n\n### Response:حسناً. لا تقلق. ستعود مرة أخرى وسترى بنفسك.'}],
#  [{'generated_text': 'Input:\nيعني مشان ما أكذب عليك بقول إني راضية و بتمنى أنجح في حياتي معكوا\n\n### Response:هل يمكن أن تخبرني كيف أصل إلى هناك من فضلك ؟'}],
#  [{'generated_text': 'Input:\nو اعتبرنا موافقين، و بالوقت اللي إنت بتحدده بنطلب لك ايد علا، ولا شو رايك يا فرج؟\n\n### Response:نرغب في مزيد من الوقت ، من فضلك.'}],
#  [{'generated_text': 'Input:\nو كمان أخته و أبوه في السجن، إشي حلو كثير\n\n### Response:إنها جميلة جداً ، أليس كذلك ؟'}],
#  [{'generated_text': 'Input:\nلعاد مش أحسن من العيشه لحالي؟ بعدين كامل شب مخه نظيف وبسببه قاعد بلعب بالمصاري لعب\n\n### Response:هل لي أن أستدعي طبيباً متخصصاً في أمراض الأنف والأذن والحنجرة ؟'}],
#  [{'generated_text': 'Input:\nبتحاول تخفي حرجك من الانسانه يلي اخذت منك وعد رجال وصدقتك\n\n### Response:حاولت أن تخفي ألمك من الشخص الذي أخذ تعهد على صداقتك.'}],
#  [{'generated_text': 'Input:\nبتعرفي يانهيل اذا قمتي ان شاءالله بالسلامه واجاني ولد بدي اسميه امل واذا بنت\n\n### Response:هل لك أن تخبرني كيف يمكنني أن أقوم بالحج إلى بيت الله تعالى ؟'}],
#  [{'generated_text': 'Input:\nمدام ممتاز ليش ما تشغل اخوك يزن معك و تعمله هالصنعة\n\n### Response:من فضلك اتبع التعليمات الصادرة من موظفينا.'}],
#  [{'generated_text': 'Input:\nهذا رح يوفر علي المقدمه و يخليني ادخل بالموضوع مباشرةً\n\n### Response:هذا سيجعلني أدخل في الموضوع مباشرة.'}],
#  [{'generated_text': 'Input:\nوليش مش قادره بس اقولك هلأ بعملك فنجان قهوه وبتحكي على كيف كيفك\n\n### Response:لا أستطيع أن أقول لك ما هو فنجان القهوة الذي تتحدثين عنه. هل يمكنك أن تخبرني كيف حالك ؟'}],
#  [{'generated_text': 'Input:\nالي من حقه يطلب نهيل و ابوي لازم ينفذلها الي بدها اياه\n\n### Response:من حقك أن تطلب من والدي أن يفاوضها على ما تريد ، من حقك أيضاً المطالبة بها.'}],
#  [{'generated_text': 'Input:\nكان يوم حلو كثير كثير ما رح انساه طول حياتي \n\n### Response:لقد كان يوماً رائعاً جداً كثيراً ما استمتعت به.'}],
#  [{'generated_text': 'Input:\nما بدي أحكي كلام يدايقك، عشان هيك بفضل ما نحكي بهالموضوع\n\n### Response:لا أريد أن أحكي كلاماً غير مهذب ، حتى لا أبدو غير ناضج.'}],
#  [{'generated_text': 'Input:\nعرفت إنه مرحبا بهالزمن ما حدا بحكيها إلا إذا بده مصلحة \n\n### Response:عرفت أنه مرحب به في هذا الوقت من العام. من فضلك احتفظ بالباقي لك.'}],
#  [{'generated_text': 'Input:\nإذا محتاجه الوقت عشان توخذي قرار بنأجل الحكي في هالموضوع\n\n### Response:من فضلك, من فضلك.'}],
#  [{'generated_text': 'Input:\nأبو جمال، أنا عندي بريكات جديدة و بنفس سعر السوق هاه إذا ما بدك جيبهم من عند جاري\n\n### Response:هل يمكن أن أؤجر سيارتك لمدة شهر من فضلك ؟'}],
#  [{'generated_text': 'Input:\nبابا أنا عمري ما كنت متأكدة من اللي بعمله قد ما أنا متأكدة هلأ\n\n### Response:هل من الممكن أن تخبرني عن مكان تواجدي الآن ؟'}],
#  [{'generated_text': 'Input:\nأنت زرعت بيننا نبتة صالحة، و إحنا مش أرض بور يابا إحنا أرض خصبة\n\n### Response:لقد زرعنا في أنفسنا نباتاً صالحاً ، و نحن لا نستطيع أن نفعل ذلك بمفردنا.'}],
#  [{'generated_text': 'Input:\nيعطيها حقوقها و يحل عنا آه، اصلًا هي و البيبي اللي في بطنها بعيونا بنحطهم\n\n### Response:يساعدها في الحصول على حقائبها وحقائب البيبي ، من فضلك.'}],
#  [{'generated_text': 'Input:\nبس ما كان لازم تسكت، أنت رح تجنني، العيلة كلها رح تجنني، يا رجل الي متقدملها غني غني غني فوق ما تتصور غني يعني لو طلبتوا منه لبن العصفور بجيبه\n\n### Response:لم يكن من الضروري أن ترفع صوتك ، من فضلك ارفع صوتك. أنت لا تريد أن ترفع صوتاً مرتفعاً. هل تريد أن تقول كلاماًاً سيئاً ؟'}],
#  [{'generated_text': 'Input:\nو ليش ما بدها توافق؟ شو اللي ناقصك؟ طيب و ابن حلال مثل ابوك و اخوانك كلهم، يلا عاد روح على شغلك أنا كمان وراي شغل و لازم أشوفه يلا\n\n### Response:لماذا لا تقبل هذه الموافقة ؟ كيف تريدها ؟ ماذا عن ابنائك أيضاً ؟ حسناً عليك أن تأخذ الأمر على أن يكون على ما يرام.'}],
#  [{'generated_text': 'Input:\nلكن لما عشت بينهم واعرفتهم، حسيت إني فعلًا بختلف عنهم لكن مش زي ما أنا ما كنت مفكره، بالعكس\n\n### Response:عندما كنت أعيش معهم أدركت الفروق بيننا لكن لم أشعر أنني أفعله. بالضبط كما أنا لم أشعر بالرغبة في ذلك. حقيقة الأمر مختلف تماماً.'}],
#  [{'generated_text': 'Input:\nطمعانين! الشاطر ينهب، و هو راخي لهم الحبل و ساكت!\n\n### Response:إنهم لا يروقهم ذلك. إنه مشغول جداً.'}],
#  [{'generated_text': 'Input:\nفمن الطبيعي إنه هاي الست رضا تحاول تغير من وضعها\n\n### Response:من الطبيعي أن تحاول هذه السيدة تغيير وضعها.'}],
#  [{'generated_text': 'Input:\nيعني هاي صباحية مباركة و يوم مبارك الله يرضى عليكي يابا\n\n### Response:هل هذه هي صباحية سعيدة أم يوم شؤم ؟'}],
#  [{'generated_text': 'Input:\nمش معقول حسب كلامكوا إنكوا تكسبوا تسعة آلاف دينار في شهر!\n\n### Response:ليس صحيحاً حسب قولكم إنكم تكسبون تسعة آلاف دولاراً في الشهر.'}],
#  [{'generated_text': 'Input:\nإذا بتعزني بجد بترجع على بيتك و من غير اعتراض و هسا\n\n### Response:إذا كنت تحب أن تعيش بمفردك, من فضلك لا بد أن يكون معك أحد أفراد أسرتك.'}],
#  [{'generated_text': 'Input:\nمبدئيًا رح أكتب لك هاظ العلاج مشان يخفف عليها، و رح نشوف شو بصير معانا\n\n### Response:أود أن أحجز غرفة بسريرين.'}],
#  [{'generated_text': 'Input:\nشو يا مرة ابوي مش انت صاحبة الفكرة إنه أبوي يبني العمار؟\n\n### Response:هل يمكنك أن تعطيني رقم تليفوني من فضلك ؟'}],
#  [{'generated_text': 'Input:\nهي الي وقفت مع أخوي عاصم و حققتله حلمه، هي الي ما بتعصيلك أي أمر يابا، هي الي حبتنا، بتعمل كل اشي مشان رضانا يابا، ليش نحملها ذنوب ما عملتها\n\n### Response:إنها التي تسببت في إصابة أخوي بتمزق في أربطة المفصل ، أليس كذلك يا سيدي ؟'}],
#  [{'generated_text': 'Input:\nاه يا بيك، فهمني هسع كيف صارت الشغلة، مش غلط اني افهم يعني \n\n### Response:هل من الممكن أن تخبرني كيف بدأت المحادثة ، من فضلك ؟'}],
# ...
#  [{'generated_text': 'Input:\nالحجر الأمني يا حبيبي عشان أعرف أنام، انام الليل الطويل الطويل\n\n### Response:الحجر الأمن يا سيدي. أريد أن أنام ليلاً طويلاً.'}],
#  [{'generated_text': 'Input:\nو بالنسبة للورثة الكبير دايماً هو اللي بكون الواصي على أموال الصغار و اليتامى و الأرامل\n\n### Response:هل لي أن أشتري بعض التذكارات من السوبر ماركت الكبرى ؟'}],
#  [{'generated_text': 'Input:\nاكم مرة أنا بدي أقلك إنو الناس مقامات و هذول أكابرية المنطقة كلياتها، و المقامات لما بتخرفوا مع بعض الناس الصغار الي زيك بوكلوا هوا و بسكتوا، لا لا العمرة أوعى بتروح العمرة، سجلوني رايح معكم تفو\n\n### Response:كم مرة أود أن أقلك أن هؤلاء الناس هم أكابري المنطقة تماما ، ولذا فإن مقامات هؤلاء الناس لا ينبغي أن تكون مدعاة للفتنة. من فضلك سجل اسمك في سجل الحموات.'}],
#  [{'generated_text': 'Input:\nمشاكل شو يا شفيق،هو انت بتفكرني رضيت بالاتفاق تبعهم هيك يعني\n\n### Response:معي حقائبي ، من فضلك.'}],
#  [{'generated_text': 'Input:\nما شاء الله! شو بشوفك قاعد و مبسوط و مبرطع و كأنه ما عليك شغل بالدار\n\n### Response:حسناً سيدي. هل من الممكن أن تحضر لي كوباً من الخمر الأحمر ؟'}],
#  [{'generated_text': 'Input:\nاه على أيام الدورة العكسرية بالجزائر، ذكرتني فيما مضى يا فهد\n\n### Response:هل من الممكن أن تخبرني كيف أصل إلى هناك ؟'}],
#  [{'generated_text': 'Input:\nانا متفاجئ هذا أحلى خبر سمعته خلال أربعة و عشرين ساعة، يعني بلا مؤاخذة بس شو سر هالعفو الملكي؟\n\n### Response:أنا مسرور جدا بهذا الخبر الذي أسعدني كثيراً.'}],
#  [{'generated_text': 'Input:\nلازم تاخد معاك كمان خروف محشي، اه ولّا انتا ابو العبد هز و لبد. و بالمرة يا حبيبي اشتري لمرتك حبيبتك اسوارة دهب بهالمناسبة\n\n### Response:يجب أن تأخذ معاك أيضاً خروفاً محشوياً ، من فضلك. هيا يا سيدي اشتري لزوجتك سواراً دهب كهدية.'}],
#  [{'generated_text': 'Input:\nهاظا يا سيدي زقطتو فالحارة، ماسك أربعة و بخبص فيهم\n\n### Response:أوه ، يا سيدي ، لقد سقطت من الطابق الرابع. هل يمكنك أن تخبرني كيف سقطت من النافذة ؟'}],
#  [{'generated_text': 'Input:\nهو اليوم رسمي رح يرَوِّح، و اذا اجى و ما لقاه والله لينخرب بيتي\n\n### Response:هذا اليوم رسمي ، و إذا لم يأت بعد فسأفعله مرة أخرىً. هل سأفعلها مرة أخرى ؟'}],
#  [{'generated_text': 'Input:\nما انت مقطع البنات يا أخوي، يقطعك في هالمنظر، زي الفولز دبركمين عاملة حادث\n\n### Response:هل يمكنك أن تخبرني كيف أصل إلى المحطة ؟'}],
#  [{'generated_text': 'Input:\nطالما ثلاثتكم متفقين لليش اللت و العجن الزيادة ، خلينا نسحب حالنا و نطيح عالزلمة و نعتذرله حقه علينا\n\n### Response:من فضلك, احتفظ بالباقي لك.'}],
#  [{'generated_text': 'Input:\nتنساش، بس توصل غاد بتشوف أي واحد من صحابك، و بتقله يقولك شو اسم أبو العبد النسناس؛ لأنو عيب و مش منيحة بحقنا نوديلو المكتوب بدون اسم. لازم نكتب اسمو عليه.\n\n### Response:تنسّش ، ولكنك لا تجد أحداً بالقرب منك ، وترحل دون أن تقول أي شيء. هلا أخبرتك أن تكتب اسمي على هذه الاستمارة ، من فضلك ؟'}],
#  [{'generated_text': 'Input:\nولك الهبلة اللي ما بتوخذو لسلامة بعد اللي صرلو و التغيير اللي حصلوا، هاظا راجع من أميركا مليان مصاري، معاه مصاري بتوكلهاش النيارين، و بعدين الأهم من هيك انو عقلو رجعلو\n\n### Response:من فضلك أعطني تقريراً عن حالة الطقس غداً صباحاً.'}],
#  [{'generated_text': 'Input:\nشو يا واطي! بتبيع حليب و انت ما معكش؟ بتتخوث عالناس؟\n\n### Response:ماذا تبيع ؟ هل تبيع حليب أطفالك وأنت لا تريد ذلك ؟'}],
#  [{'generated_text': 'Input:\nشو بدي أقول يا سيادة المارشال رسمي يعني بصفتك انت بتشتغل مع الحكومة\n\n### Response:ما هو الشيء الذي تريد أن تقوم به يا سيدي ؟'}],
#  [{'generated_text': 'Input:\nما شاء الله ما شاء الله. ولك التراب قلب حنة يا فضل، شو عملت للحمارة تنها اقتنعت؟\n\n### Response:لقد استمتعت كثيراً بهذا المساء.'}],
#  [{'generated_text': 'Input:\nابن النسناس ابن الناس، بوصله بكل كرم لحارة الذكر وبعديها بتلطف وبالله واسم الله بوصل الممرض لحارة أبو فجلة و برجع بسلم المفاتيح الي انا أبو العبد هز و لبد\n\n### Response:هل يمكن أن تخبرني عن مكان تواجدي في هذا المكان ؟'}],
#  [{'generated_text': 'Input:\nبس انا بدي اياك تروحي عند ابو العبد تخليه يشوف ابو يزن يتنازل عن حقو\n\n### Response:من فضلك أعطني إيصالاً لأقرب محطة مترو أنفاق.'}],
#  [{'generated_text': 'Input:\nالله يقطع معروف واليوم اللي عرفناه فيه معروف، اكم مرة قلتلك يا أبو عطا هاظا معروف واحد نصاب كذاب والله لو تعطيه مليون فرصة ما بنصلح حاله\n\n### Response:حسناً ، شكراً جزيلاً.'}],
#  [{'generated_text': 'Input:\nهاظا المرض ما بعرف لا دار ابو فجلة و لا دار الدكر و لا النسناس حتى\n\n### Response:لا أعرف شيئاً عن هذا المرض الخطير الذي لا يمكن تشخيصه إلا من خلال الفحص الطبي.'}],
#  [{'generated_text': 'Input:\nما استحطيت؟ أنت موديني عالموت! هو فش في هالدنيا الا أبو عطا مش سامع شو صاير بالصين\n\n### Response:هل أستطيع أن آخذ حقائبي إلى المطار ؟'}],
#  [{'generated_text': 'Input:\nهسا أنا بهمنيش غير إنو يتشكل وفد رسمي يمثل هاي القرية الظالم أهلها و نخلص\n\n### Response:هل من الممكن أن أحصل على نسخة من جواز السفر الخاص بي ؟'}],
#  [{'generated_text': 'Input:\nهان كل اشي راح يكون على المكشوف، و هم ثلاث مشاريع و انتوا ثلاث عيل\n\n### Response:كل شيء سوف يكون على ما يرام ، وسوف يكون هناك ثلاثة عشر مشروعاً في غضون ثلاثة عشر يوماً.'}],
#  [{'generated_text': 'Input:\nشوف يا فهمي، أبو جبر بدو يشكي بدوش يشكي في حق عام، في ناس تضرروا نفسياً من اللي بصير يا زلمة\n\n### Response:حسناً.'}],
#  [{'generated_text': 'Input:\nشو يا أبو الفوز عشان قلتلك بدي إياك تسافر على الصين بطلت تفتح دكانتك\n\n### Response:من فضلك احتفظ بالباقي في صندوق السيارة.'}],
#  [{'generated_text': 'Input:\nيم مجيتش تمرظ إلا هسا؟ ترا انته لا للسدي و لا للهدي، مثلك مثل مسعود الحذر\n\n### Response:هل لي أن ألتقط صوراً تذكارية من فضلك ؟'}],
#  [{'generated_text': 'Input:\nشوف يا حضرة الملازم أنا هجيت من داري و رحت عند دار أبوي كله من تحت راس سلامة، يا بتشوفولي حل بسلامة يا بهج من البلد كلها\n\n### Response:حسناً.'}],
#  [{'generated_text': 'Input:\nهنا من سوق هوانان للمأكولات البحرية في مدينة ووهان الصينية\n\n### Response:هنا من متجر هوان هوان للمكالمات الهاتفية في مقاطعة هونان بوسط وسط الصين.'}],
#  [{'generated_text': 'Input:\nنسيت يا زلمة بس بقينا قاعدين عند النار و قلتلي بدنا نرُوح و نعاكس خالتي ام فخري عشان انت تدافع عنها؟\n\n### Response:لقد نسيت يا سيدي. هل تريد أن نقضي وقتاً ممتعا معك ؟'}],
#  [{'generated_text': 'Input:\nفش عندهم شرش هالذكاء، من وين جايبيته اه قوليلي؟ اكيد مني يعني طالعة علي!\n\n### Response:هل يوجد لديهم شرش في هذا الذكاء ، من أين يأتيه ؟ هل هي قادمة من بعيد جداً ؟ هلا أخبرتني من فضلك ؟'}],
#  [{'generated_text': 'Input:\nهلا! هلا و مليون مرحبا! هلا بالحكومة نورتوا الحارة والله، خير شو في؟\n\n### Response:هلاّ. هلاّ وألف مرحباً بكم جميعاًً. هل من الممكن أن تخبرني كيف حالكم ؟'}],
#  [{'generated_text': 'Input:\nولّا يعمي ما همه الشرطة لموا كل أهل البلد عن جنب و طرف، كنسوهم تكنيس و حطوهم فالسجن\n\n### Response:لا يهتم كثيراً ما يهتم هو أيضاً بالشرطة. من المهم جداً أن يظلوا في مكان آمن.'}],
#  [{'generated_text': 'Input:\nهلئ سيبنا من سيرتو لأبو جبر و قلي لساك على وعدك ولا كالعادة؟ بدنا نسافر ولا لأ شو؟\n\n### Response:هل لك أن تخبرني كيف أصل إلى هناك من فضلك ؟'}],
#  [{'generated_text': 'Input:\nإن شاء الله لجرحك جرح ما تقوم منو. اسمع! ترا انا عارفكم انتو مساعدين المخاتير مش قلال،بتخوفو. بس يا خوفي، يا خوفي تطلع مثل معروف الدكر اللي حبس أبو عطا لقطمك تقطيم\n\n### Response:حسناً.'}],
#  [{'generated_text': 'Input:\nبتعرف يابا، هادا أبو ناصر طلع لا سايقها انتماء و وطنية ولا حتى سايق عرباي\n\n### Response:هل من الممكن أن تخبرني كيف أتحكم في مشاعري وأحاسيسي ؟'}],
#  [{'generated_text': 'Input:\nحبيبة قلبي يا وداد، جبتلك ذهبات تعويض عن الذهبات اللي انسرقوا هوأنا بهونلي بزعلتش\n\n### Response:عذراً.'}],
#  [{'generated_text': 'Input:\nطيب تتفلفسش تتفلفسش، هسا بتضلك رايح عأم الحيطان من هناك بتجيبلي معاك أبو الشنتات و أنت راجع عكفر اللوز بتشحطلي معروف الذكر بطريقك\n\n### Response:هل من الممكن أن تخبرني عن كيفية الوصول إلى هناك من هناك ، من فضلك ؟'}],
#  [{'generated_text': 'Input:\nلا والله يا زلمة، صح معيش حليب بس الحمارة تعبانة و مش قادر احمّل عليها حليب\n\n### Response:حسناً ، شكراً جزيلاً.'}],
#  [{'generated_text': 'Input:\
#  [{'generated_text': 'Input:\nخمسة، أبو طاسة خمسة، أبو شحادة خمسة، معروف الدكر خمسة، بشرط أن يزرعها لا يبيعها و لا ينصب بها\n\n### Response:خمسة ، السيدان خمسة ، السيد شحادة خمسة ، من فضلك.'}],
#  [{'generated_text': 'Input:\nطيب مدام هيك خلينا نرجع عالبلد، ولا شو رأيك يا عمي ابو جبر؟\n\n### Response:حسنا ، سنعود إلى بلدنا ، أليس كذلك يا سيدي ؟'}],
#  [{'generated_text': 'Input:\nشو هاظ يا أبو ناصر، أنا الفار بلش يلعب في عبي، بدي أقول دشرت كل كفر الوز و جايبني هان على البر، اسمع لقلك بدك تسوي صاحب معي؟\n\n### Response:هل هذه هي أول رحلة خارجية لي ، من فضلك.'}],
#  [{'generated_text': 'Input:\nو لك انا مش حاسدته بس انا مستغربة نعم هو كان مغلبنا بس والله طلع أصيل و ما نسينا\n\n### Response:أنا لست متأكداً ما إذا كنت سأعتني حقاً أم لا.'}],
#  [{'generated_text': 'Input:\nيقطع خلفك زي ما قطعت خلفي، شو هو الخراف شو قلت أنا؟ ولا حكيت اشي قلت أبو عطا يسد شوي من ديناته القدام قبل ما يسحب جديد، هاد الطبل أبو فايز ما عرفش يوصلك الفكرة\n\n### Response:توقف خلفك مثل ما توقف خلفك خلفك تماماً ، من فضلك.'}],
#  [{'generated_text': 'Input:\nالصحيح لا، الي استوى هو أبو عطا تويتي ذبحت الي نفضو ملش شغلة فالبلد غير أبو العبد و أبو ناصر من شقة و انت من شقة ثانية، ان شاء الله تبقى صادق\n\n### Response:لا ، لقد كان ذلك صحيحاً. لقد تم ذبح السيد عطا تويتياً في شقة سكنية في بلد غير مصرح فيه من قبل السلطات. كان ذلك خطأً فادحاً لا يغتفر.'}],
#  [{'generated_text': 'Input:\nفاطمة ابو فجلة و ابتهاج النواح ابو فجلة ، فهمت علي؟\n\n### Response:هل يمكنك أن تغير هذه القيمة إلى دولارات أمريكية ؟'}],
#  [{'generated_text': 'Input:\nكنافة و بقلاوة و مطبق، بدك تحسدهم احسدهم على شي ثاني، احسدهم ع وحدتهم، مجلس قروي واحد، و رئيس مجلس قروي واحد، مش زيكم إنتو الثلاث زي بعر الغنم كل واحد بجبل\n\n### Response:كنافة بقشدة ومقلية ، من فضلك.'}],
#  [{'generated_text': 'Input:\nعمي أبو العبد، حط عينك فعيني. أكم مرة وعدتني قلتلي رح أفتحلك استوديو و مصرش هالحكي؟ أكم مرة؟\n\n### Response:هل يمكنك أن تخبرني كيف أصل إلى محطة السكة الحديدية ، من فضلك ؟'}],
#  [{'generated_text': 'Input:\nالله يخليلنا الحكومة، الله يا ربنا يعلي مراتبك يا رب\n\n### Response:حسناً ، شكراً جزيلاً.'}],
#  [{'generated_text': 'Input:\nمش كاشع؟ اعمى انت؟ شتلة زيتون. مدريتش؟ في مركز الشرطة بوزعوا في زيتون، قلت أجيب وحدة لحماتي ام فخري\n\n### Response:لا أستطيع أن أجدها.'}],
#  [{'generated_text': 'Input:\nهاظا يا ابن عمي كنت عند وزير الحكم المحلي، قدمتلو على مبادرة شبابية لحتى احنا الشباب نقود المجلس بدل الثلث ختيارية اللي انهكونا\n\n### Response:هل من الممكن أن تخبرني كيف أتحكم في درجة حرارة الغرفة ؟'}],
#  [{'generated_text': 'Input:\nفكرك أبو جبر شو رح يعمل لو يعرف إني أنا بكذب عليه و مقعدك عندي آه؟\n\n### Response:من فضلك أعطني تقريراً عن حالة الطقس غداً صباحاً.'}],
#  [{'generated_text': 'Input:\nلا شو دفنّاه؟ إحنا منستناك و منستنا ولاد عمّك، بدنا نلم شمل العيلة كلها. ملتميناش و هو عايش، منلتم عالقليلة عقبرو\n\n### Response:لا ، لا شئ من هذا ، لا شيء من هذا. سنبقى على اتصال ببعضنا البعض إلى أن ننعم جميعاً.'}],
#  [{'generated_text': 'Input:\nبدي تشاغل تحت إيدي شوفير عشان يحلالي الجو مع فاطمة جوا سيارة الشرطة\n\n### Response:هل من الممكن أن تغير هذه من فضلك ؟'}],
#  [{'generated_text': 'Input:\nبلاش تجيب سيرة مسعود الحذر يعني بلاش هيك يرن عليك و تصير مشكلة بينك و بينه\n\n### Response:من فضلك أعطني تقريراً عن حالة الطقس غداً صباحاً.'}],
#  [{'generated_text': 'Input:\nأصلاً هما دار أبو فجلة بعرفوا للعب ولا لكرة القدم\n\n### Response:هل من الممكن أن تخبرني كيف يمكنني أن ألعب كرة القدم ؟'}],
#  [{'generated_text': 'Input:\nهادا في الزمانات يا سيدي دار الدكر وقعوا في مشلكة و سيدي الله يرحمه أبو فجلة الكبير حللهم اياها و لا كان ما عمرها انحلت\n\n### Response:هذا في المكان الذي وقعت فيه المشلكة سيدي. سيدي الله يرحمنا برحمته الواسعة.'}],
#  [{'generated_text': 'Input:\nيعني أبو ناصر يودي سعيد على روسيا، و أبو العبد يودي نجم عبيروت. باكيين أحسن منّا؟\n\n### Response:هل هذه هي المرة الأولى التي أذهب فيها إلى سان فرنسيسكو ؟'}],
#  [{'generated_text': 'Input:\nالله لا يباركلو و لا يقشّعو بركة وين ما دار وجهو هالجندي. سفقني ببوز بسطارو على عصب رجلي سوالي شلل رباعي يبو عطا، حسيت حالي بطلق. يخرب بيتو، قسماً بالله رفسة حمارة أبو صابر أهون منّو\n\n### Response:من فضلك افتح فمك قليلاً قبل أن تخرج من فمك شيئاً آخر من فضلك.'}],
#  [{'generated_text': 'Input:\nقاعد بفكر و بقول لحالي: معقول المخاتير الثلاث بكرة يخربوا افتتاح المدرسة مثل ما خربوا أيام افتتاح مركز الشرطة؟\n\n### Response:أبحث عن شيء ما ، من فضلك.'}],
#  [{'generated_text': 'Input:\nيم هسا صار معروف الدكر مش عاجبك يا ابو الفوز؟\n\n### Response:أجل يا سيدي. هل من الممكن أن تحضر لي كوباً من الخمر الأحمر من فضلك ؟'}],
#  [{'generated_text': 'Input:\nو الله وصلتني تقارير بتحكي إنو فيها أراضي حلوة لدار النسناس\n\n### Response:لقد أرسلت تقريراً إلى دار المسنين تقول فيه إن هناك مساحات خضراء في دار المسنين.'}],
#  [{'generated_text': 'Input:\nلا حول ولا قوة إلا بالله، لعلمك هاي استغاثة و أنا صار وقت الصلاة، سلام عليكم\n\n### Response:لا حول و لا قوة إلا به, من فضلك.'}],
#  [{'generated_text': 'Input:\nو الجاني رح نعرفو من خطو، و وقتها رح ننزل فيه أشد العقاب\n\n### Response:حسناً.'}],
#  [{'generated_text': 'Input:\nبعدين انت بتعرف قديش اهل البلد بحترموني و بسمعوا كلامي\n\n### Response:بعد ذلك سوف تعرف أن هناك أناس طيبون من بلدك سوف يرشدونك إلى الطريق المستقيم.'}],
#  [{'generated_text': 'Input:\nعلى أساس إنو احنا مركز شرطة ام الحيطان، ما احنا من كفر اللوز يا زلمة منها فيها، بعدين بدنا نزرعهن حوالين المركز، أنا قلتلك غير نروحهن على الدور؟\n\n### Response:هل من الممكن أن تخبرني كيف أصل إلى هناك ؟'}],
#  [{'generated_text': 'Input:\nلا يا عمي، حقك علي، انا الكذاب. بس بدي اياك تعطيني تاريخ محدد و تقولي يا نجم في هاظا التاريخ بدي افتحلك استوديو، و اذا بدكش تساعدني بشوف حدا ثاني يساعدني\n\n### Response:لا يا سيدي ، لك حق عليك ، أنا الكذاب. ولكن أريدك أن تساعدني في العثور على مخرج ، من فضلك.'}],
#  [{'generated_text': 'Input:\nقصدك نصّاب و سرسري. و عشان انته نصاب زيو الدم بحن عالدم\n\n### Response:إنه مصاب بالالتهاب الشعبى.'}]]

# %%
for text in generated_text[5:10]:
    print(text[0])
    break
# Out:
# {'generated_text': ' قطرات قطرة قطرة قطرة قطرات قطرة قطرات قطرات قطرات قطر قطرة قطرات قطر قطرات قطرة قطر قطرة قطرة قطر قطرات قطراتقطر قطرات قطراتقطققطقطقطقمقطققمقطقمقمقطقطقيمقمقمقمقيمقمقيمقيمقيمقامقمقيمقامقامقامقيمقامقيمقمقامقيمقيمقمقامةقمقم'}

# %%
generated_text
# Out:
# [[{'generated_text': ' فتيات لندن يرتدين العباءات الفاتنة والفتيات الفاتنات لندن يرتدين العباءة الفاتنة الفتيات الفاتناتلندن يرتدين العباءات فاتنات لندن العباءات الفاتنه الفتيات الفاتنه الفاتناتموسيقى لندن الصاخبة وموسيقى لندن الصاخبة موسيقى لندن الصاخبة والموسيقى لندن الصاخبة الموسيقى لندن الصاخبةالمزيد من الموسيقى في لندنالموسيقى في لندنالمايستروالموسيقىفي لندن'}],
#  [{'generated_text': ' جزيرة الكنز جزيرة الكنز جزر الكنز جزيرة المفقود جزيرة الكنز جزرة الكنز جزر المفقود جزيرة المفقود جزر المفقود جزر مفقود جزر مفقود جزيرة المفقود جزرة المفقود جزمة المفقود جزمه المفقود جزم مفقود جزمة مفقود جزمه مفقود جزمته المفقود جزمت المفقود جزمته مفقود جزم المفقود جزمات المفقود جزومات المفقود جزامات المفقود'}],
#  [{'generated_text': ' قطرات قطرة قطرة قطرة قطرات قطرة قطرات قطرات قطرات قطر قطرات قطرات قطرة قطر قطرات قطرة لقطر قطرات قطرات لقطر قطرات لقطر قطر قطرات لقطرقطر قطرات لقطر قطرة لقطر قطر لقطرقطرقطرقطرقطقطقطقمقطقطققطقمقمقطققمقطقمققطقطقيمقمقمقمقيمقمقيمقيمقيمقامقم'}],
#  [{'generated_text': ' قطرات قطرات قطرات قطرة قطرة قطرة قطرات قطرة قطرات قطر قطرات قطرات قطر قطرة قطرة قطر قطرة قطر قطرات قطرة قطر قطر قطرات قطر قطر قطرقطرقطرريلاقطقطقطرققطرقققطرققمقطقطققطقطقمققطقمقمققممقعدقمقمقممقاعدقمقمقيمقمقيمقيم'}],
#  [{'generated_text': ' جريدة الدستور جريدة الدست
#  [{'generated_text': ' جزيرة الكنز المفقودة جزيرة الكنز المفقود جزيرة الكنز مفقودة جزيرة الكنز مفقود جزيرة الكنز مفقودين جزيرة الكنز فقدان جزيرة الكنز اختفاء جزيرة الكنز اكتشاف جزيرة الكنز باكتشاف جزيرة الكنز لاكتشاف جزيرة الكنز لمعرفة جزيرة الكنز للتعرف على جزيرة الكنز والتعرف على الجزيرة للتعرف على الجزيرة التعرف على الجزيرة تعرف جزيرة الكنز وتعرف جزيرة الكنز معرفة جزيرة الكنز بمعرفة جزيرة الكنز ومعرفة جزيرة الكنز تعرف'}],
#  [{'generated_text': ' عصرية أنيقة عصرية أنيقة أنيقة أنيقة أناقة أنيقة أناقة عصرية أنيقة أناقة أناقة عصرية أناقة عصرية الأناقة أناقة عصرية الأنيقة أناقة عصرية إلقاء القبض على العصرية الأنيقة الأنيقة الأنيقة أناقة أناقة أناقة العصرية أناقة عصرية القاء القبض على المعاصرة الأنيقة الأنيقة الأناقة أناقة أناقة المعاصرة أناقة عصرية ألقي القبض على الكلاسيكية الأنيقة الأنيقة الكلاسيكية أناقة أناقة الكلاسيكية أناقة عصرية إلق القبض على التقليدية الأنيقة'}],
#  [{'generated_text': ' قطرات قطرات قطرات قطرة قطرة قطرة قطرات قطرة قطرات قطرات قطر قطرات قطراتقطر قطرات قطراتقطقط قطرات قطرات قطقطقط قطرة قطراتقط قطراتقط قطرةقط قطرة قطرةقطقطقط نقطةقطقط نقطتينقطقط نقاطقطقط نقطقطقط النقاطقطقط النقطقطقط النقطةقطقطنقطةقطقطقطةقطقط نققط'}],
#  [{'generated_text': ' جزيرة الكنز جزيرة الكنز لعبة جزيرة الكنز رحلة جزيرة الكنزرحلة جزيرة الكنز زيارة جزيرة الكنزجولة جزيرة الكنز جولة جزيرة الكنز لزيارة جزيرة الكنزريطة جزيرة الكنز خريطة جزيرة الكنزخريطة جزيرة الكنز الخريطة الخريطة خريطة الجزيرة الكنز خريطة الكنز الخريطة خريطة الكنز خريطة كنز خريطة كنزخريطة كنز كنزكنز كنز كنز كنز كنوز كنز كنز معلومات معلومات معلوماتمعلومات معلومات معلومات'}],
#  [{'generated_text': ' جريدة الجمهوريةجريدة الجمهورية'}],
#  [{'generated_text': ' قطرات ندى قطرة ندى قطرات ندى قطراتندى قطرة ندى قطرةندى قطراتندى قطراتندي قطراتندي قطرة قطرةندى قطرة قطرةندي قطرات ردينة ندى قطرة قطرة ندى ندى قطرةندي قطرة ندى نقطة ندى ندىنقطة ندى ندى ندى نقطةندى ندى نقطةندي ندى نقطةنديدة ندى ندى قطعة قطعة قطعةقطعة قطعةقطعةقطعةقطعةقطقطقط'}],
#  [{'generated_text': ' جزيرة الكنز جزيرة الكنز جزر الكنز جزر الكنوز جزر الكنوز الجزر جزر الكنوز الكنوز الكنوز الكنز الكنوز الكنز الكنز الكنز كنز الكنوز الكنز كنوز الكنوز الكنوز كنز الكنوز الكنوز كنوز الكنوز كنوز كنوز كنوز منتديات قلعة الحصن قلعة الحصن حصن الحصن حصن القلعة حصن القلعة الحصن حصن قلعة الحصن حصون قلعة الحصن قلاع قلعة الحصن الحصون قلاع قلعة القلعة الحصون قلاع القلعة قلاع القلعة'}],
#  [{'generated_text': ' جريدة الدستور جريدة الدست
#     evaluation_strategy = "epoch",  # Evaluate every 'eval_steps' steps
#     overwrite_output_dir=True,
#     per_device_train_batch_size=16,
#     gradient_accumulation_steps=8,
#     num_train_epochs=10,
#     logging_strategy="epoch",  # Log training loss every epoch
#     save_strategy="epoch",  # Save checkpoints every epoch

# )

# trainer = Trainer(model=model, tokenizer=tokenizer, args=training_args)

# trainer = Trainer(
#     model=model,
#     args=training_args,
#     ...
# )

# # Load the checkpoint
# trainer.load_model("path_to_checkpoint_directory")

# %% [markdown]
# ### Evaluation

# %%
ls lm-evaluation-harness/
# Out:
# ls: cannot access 'lm-evaluation-harness/': No such file or directory

# %%
# clone llm-evaluation-harness
# !git clone https://github.com/EleutherAI/lm-evaluation-harness
# cd lm-evaluation-harness
# !pip install -e .

# %% [markdown]
# #### Zero-shot model

# %%
# zero-shot pre-trained model
# !lm_eval --model hf \
    --model_args pretrained="gpt2" \
    --tasks sst2 \
    --device cuda:0 \
    --batch_size auto:4
# Out:
# 2024-01-24:05:24:58,724 INFO     [utils.py:160] NumExpr defaulting to 2 threads.
# 2024-01-24:05:24:58,987 INFO     [config.py:58] PyTorch version 2.1.0+cu121 available.
# 2024-01-24:05:24:58,988 INFO     [config.py:95] TensorFlow version 2.15.0 available.
# 2024-01-24:05:24:58,989 INFO     [config.py:108] JAX version 0.4.23 available.
# 2024-01-24 05:24:59.465533: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-01-24 05:24:59.465590: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-01-24 05:24:59.466821: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-01-24 05:25:00.661867: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-01-24:05:25:04,183 INFO     [__main__.py:156] Verbosity set to INFO
# 2024-01-24:05:25:08,391 WARNING  [__init__.py:194] Some tasks could not be loaded due to missing dependencies. Run with `--verbosity DEBUG` for full details.
# 2024-01-24:05:25:12,437 WARNING  [__init__.py:194] Some tasks could not be loaded due to missing dependencies. Run with `--verbosity DEBUG` for full details.
# 2024-01-24:05:25:12,438 INFO     [__main__.py:229] Selected Tasks: ['sst2']
# 2024-01-24:05:25:12,452 INFO     [huggingface.py:148] Using device 'cuda:0'
# 2024-01-24:05:25:14,506 WARNING  [task.py:603] [Task: sst2] metric acc is defined, but aggregation is not. using default aggregation=mean
# 2024-01-24:05:25:14,506 WARNING  [task.py:615] [Task: sst2] metric acc is defined, but higher_is_better is not. using default higher_is_better=True
# 2024-01-24:05:25:17,976 INFO     [task.py:340] Building contexts for task on rank 0...
# 2024-01-24:05:25:18,436 INFO     [evaluator.py:319] Running loglikelihood requests
#   0% 0/1744 [00:00<?, ?it/s]Passed argument batch_size = auto:4.0. Detecting largest batch size
# Determined largest batch size: 64
#  18% 321/1744 [00:04<00:10, 132.87it/s]Passed argument batch_size = auto:4.0. Detecting largest batch size
# Determined largest batch size: 64
# 100% 1744/1744 [00:10<00:00, 167.90it/s]
# fatal: not a git repository (or any of the parent directories): .git
# hf (pretrained=gpt2), gen_kwargs: (None), limit: None, num_fewshot: None, batch_size: auto:4 (64,64,64,64)
# |Tasks|Version|Filter|n-shot|Metric|Value |   |Stderr|
# |-----|------:|------|-----:|------|-----:|---|-----:|
# |sst2 |      1|none  |     0|acc   |0.5505|±  |0.0169|

# %%
# !lm_eval --model hf \
    --model_args pretrained=/content/output/gpt2 \
    --tasks sst2 \
    --device cuda:0 \
    --batch_size auto:4
# Out:
# 2024-01-24:05:25:51,870 INFO     [utils.py:160] NumExpr defaulting to 2 threads.
# 2024-01-24:05:25:52,137 INFO     [config.py:58] PyTorch version 2.1.0+cu121 available.
# 2024-01-24:05:25:52,138 INFO     [config.py:95] TensorFlow version 2.15.0 available.
# 2024-01-24:05:25:52,139 INFO     [config.py:108] JAX version 0.4.23 available.
# 2024-01-24 05:25:52.615154: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-01-24 05:25:52.615202: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-01-24 05:25:52.616432: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-01-24 05:25:53.710163: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-01-24:05:25:56,950 INFO     [__main__.py:156] Verbosity set to INFO
# 2024-01-24:05:26:02,001 WARNING  [__init__.py:194] Some tasks could not be loaded due to missing dependencies. Run with `--verbosity DEBUG` for full details.
# 2024-01-24:05:26:05,933 WARNING  [__init__.py:194] Some tasks could not be loaded due to missing dependencies. Run with `--verbosity DEBUG` for full details.
# 2024-01-24:05:26:05,934 INFO     [__main__.py:229] Selected Tasks: ['sst2']
# 2024-01-24:05:26:05,943 INFO     [huggingface.py:148] Using device 'cuda:0'
# 2024-01-24:05:26:06,782 WARNING  [task.py:603] [Task: sst2] metric acc is defined, but aggregation is not. using default aggregation=mean
# 2024-01-24:05:26:06,782 WARNING  [task.py:615] [Task: sst2] metric acc is defined, but higher_is_better is not. using default higher_is_better=True
# 2024-01-24:05:26:10,511 INFO     [task.py:340] Building contexts for task on rank 0...
# 2024-01-24:05:26:11,180 INFO     [evaluator.py:319] Running loglikelihood requests
#   0% 0/1744 [00:00<?, ?it/s]Passed argument batch_size = auto:4.0. Detecting largest batch size
# Determined largest batch size: 64
#  18% 321/1744 [00:04<00:10, 130.42it/s]Passed argument batch_size = auto:4.0. Detecting largest batch size
# Determined largest batch size: 64
# 100% 1744/1744 [00:10<00:00, 162.45it/s]
# fatal: not a git repository (or any of the parent directories): .git
# hf (pretrained=/content/output/gpt2), gen_kwargs: (None), limit: None, num_fewshot: None, batch_size: auto:4 (64,64,64,64)
# |Tasks|Version|Filter|n-shot|Metric|Value |   |Stderr|
# |-----|------:|------|-----:|------|-----:|---|-----:|
# |sst2 |      1|none  |     0|acc   |0.5998|±  |0.0166|

# %% [markdown]
# ### Prompting
# - Once we have trained the model to follow instructions, we can prompt that model to generate a response.
# - We will be using HF's generation pipeline to prompt our trained model.
# - After training the model with a particular prompt wrapper it is advised to use the same prompt format during inference.

# %%
import time
import transformers
from transformers import AutoTokenizer, AutoModelForCausalLM
import torch
import os

# %%
# Load tokenizer and trained model and then create chatbot pipeline
tokenizer = AutoTokenizer.from_pretrained("/content/output/gpt2")
model = AutoModelForCausalLM.from_pretrained("/content/output/gpt2", device_map="cuda:0")

chatbot = transformers.pipeline(
    "text-generation",
    model=model,
    tokenizer=tokenizer,
)

# %%
# pip show torch

# %%
# format the prompt
text = "What is Machine Learning?"

prompt = PROMPT_DICT['prompt_no_input'].format(instruction=text)

# %%
prompt
# Out:
# 'Below is an instruction that describes a task. Write a response that appropriately completes the request.\n\n### Instruction:\nWhat is Machine Learning?\n\n### Response:'

# %%
sequences = chatbot(
    prompt,
    do_sample=True,
    temperature=0.1,
    top_p=0.4,
    num_return_sequences=1,
    eos_token_id=tokenizer.eos_token_id,
    max_new_tokens=64,
    return_full_text=False
)
# Out:
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.

# %%
# !ps ux

# %%
print(sequences[0]['generated_text'])
# Out:
# Machine learning is a new field of research that has been gaining momentum in recent years. Machine learning is a new field of research that has been gaining momentum in recent years. Machine learning is a new field of research that has been gaining momentum in recent years.
#
# Machine learning is a new field of research that has been

# %% [markdown]
# #### Next Tutorial - Prompting
